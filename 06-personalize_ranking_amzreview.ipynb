# %% [markdown]
# # Personalize Ranking Example <a class="anchor" id="top"></a>
#
# In this notebook, you will choose a dataset and prepare it for use with Amazon Personalize Batch Recommendations.
#
# 1. [Choose a dataset or data source](#source)
# 1. [Prepare your data](#prepare)
# 1. [Create dataset groups and the interactions dataset](#group_dataset)
# 1. [Configure an S3 bucket and an IAM role](#bucket_role)
# 1. [Import the interactions data](#import)
# 1. [Create solutions](#solutions)
# 1. [Create campaigns](#create)
# 1. [Interact with campaigns](#interact)
# 1. [Clean up](#cleanup)
#
# ## Introduction <a class="anchor" id="intro"></a>
#
# For the most part, the algorithms in Amazon Personalize (called recipes) look to solve different tasks, explained here:
#
# 1. **HRNN & HRNN-Metadata** - Recommends items based on previous user interactions with items.
# 1. **HRNN-Coldstart** - Recommends new items for which interaction data is not yet available.
# 1. **Personalized-Ranking** - Takes a collection of items and then orders them in probable order of interest using an HRNN-like approach.
# 1. **SIMS (Similar Items)** - Given one item, recommends other items also interacted with by users.
# 1. **Popularity-Count** - Recommends the most popular items, if HRNN or HRNN-Metadata do not have an answer - this is returned by default.
#
# No matter the use case, the algorithms all share a base of learning on user-item-interaction data which is defined by 3 core attributes:
#
# 1. **UserID** - The user who interacted
# 1. **ItemID** - The item the user interacted with
# 1. **Timestamp** - The time at which the interaction occurred
#
# We also support event types and event values defined by:
#
# 1. **Event Type** - Categorical label of an event (browse, purchased, rated, etc).
# 1. **Event Value** - A value corresponding to the event type that occurred. Generally speaking, we look for normalized values between 0 and 1 over the event types. For example, if there are three phases to complete a transaction (clicked, added-to-cart, and purchased), then there would be an event_value for each phase as 0.33, 0.66, and 1.0 respectfully.
#
# The event type and event value fields are additional data which can be used to filter the data sent for training the personalization model. In this particular exercise we will not have an event type or event value.
#
# ## Choose a dataset or data source <a class="anchor" id="source"></a>
# [Back to top](#top)
#
# As we mentioned, the user-item-iteraction data is key for getting started with the service. This means we need to look for use cases that generate that kind of data, a few common examples are:
#
# 1. Video-on-demand applications
# 1. E-commerce platforms
# 1. Social media aggregators / platforms
#
# There are a few guidelines for scoping a problem suitable for Personalize. We recommend the values below as a starting point, although the [official limits](https://docs.aws.amazon.com/personalize/latest/dg/limits.html) lie a little lower.
#
# * Authenticated users
# * At least 50 unique users
# * At least 100 unique items
# * At least 2 dozen interactions for each user
#
# Most of the time this is easily attainable, and if you are low in one category, you can often make up for it by having a larger number in another category.
#
# Generally speaking your data will not arrive in a perfect form for Personalize, and will take some modification to be structured correctly. This notebook looks to guide you through all of that.
#
# To begin with, we are going to use the MovieLens 100k dataset. These are records of the movie rating behavior of its users. The data fits our guidelines with a large number for users, items, and interactions.
#
# First, you will download the dataset and unzip it in a new folder using the code below.

# %% [markdown]
# Take a look at the data files you have downloaded.

# %% [markdown]
# ## Prepare your data <a class="anchor" id="prepare"></a>
# [Back to top](#top)
#
# The next thing to be done is to load the data and confirm the data is in a good state, then save it to a CSV where it is ready to be used with Amazon Personalize.
#
# To get started, import a collection of Python libraries commonly used in data science.

# %%
## intrim solution 

# !aws s3 cp s3://sagemaker-iris-yianc/athena-result/amz-review-u-i-2015-h/2020/12/12/eed4c9c7-6b78-4e7a-bd2d-9ec9ff328e3d.csv user-item.csv
# Out:
# download: s3://sagemaker-iris-yianc/athena-result/amz-review-u-i-2015-h/2020/12/12/eed4c9c7-6b78-4e7a-bd2d-9ec9ff328e3d.csv to ./user-item.csv

# %%
import time
from time import sleep
import json
from datetime import datetime
import numpy as np
import boto3
import pandas as pd

# %% [markdown]
# Next,open the data file and take a look at the first several rows.

# %%
data_dir = './'
original_data = pd.read_csv(data_dir + 'user-item.csv', delimiter=',')
# original_data = original_data.rename(columns={0: "user", 1: "item", 2:"rating", 3:"timestamp"})
original_data.head(5)
# Out:
#    product_id        product_category  customer_id  star_rating   timestamp
# 0  B00RP4XVFU  Digital_Ebook_Purchase      9979839            5  1424649600
# 1  B00QFPEOQA  Health_&_Personal_Care      9979839            5  1424822400
# 2  B0052P21K0        Home_Improvement      9979839            5  1424304000
# 3  B00Q375GVC  Health_&_Personal_Care      9979839            5  1420243200
# 4  B00TABYZX8                Wireless      9979839            5  1424822400

# %%
original_data = original_data.rename(columns={"customer_id": "USER_ID", "product_id": "ITEM_ID", "star_rating":"EVENT_VALUE", 'timestamp':'TIMESTAMP'})
original_data.head()
# Out:
#       ITEM_ID        product_category  USER_ID  EVENT_VALUE   TIMESTAMP
# 0  B00RP4XVFU  Digital_Ebook_Purchase  9979839            5  1424649600
# 1  B00QFPEOQA  Health_&_Personal_Care  9979839            5  1424822400
# 2  B0052P21K0        Home_Improvement  9979839            5  1424304000
# 3  B00Q375GVC  Health_&_Personal_Care  9979839            5  1420243200
# 4  B00TABYZX8                Wireless  9979839            5  1424822400

# %%
original_data = original_data.drop(['product_category'], axis=1)

# %% [markdown]
# That's better. Now that the data has been successfully loaded into memory, let's extract some additional information. First, calculate some basic statistics from the data.

# %%
original_data.describe()
# Out:
#             USER_ID   EVENT_VALUE     TIMESTAMP
# count  5.592168e+07  5.592168e+07  5.592168e+07
# mean   2.895096e+07  4.299292e+00  1.395175e+09
# std    1.558575e+07  1.140404e+00  6.204552e+07
# min    1.000500e+04  1.000000e+00  8.079264e+08
# 25%    1.501766e+07  4.000000e+00  1.384992e+09
# 50%    2.837718e+07  5.000000e+00  1.417997e+09
# 75%    4.363551e+07  5.000000e+00  1.429402e+09
# max    5.309657e+07  5.000000e+00  1.440979e+09

# %% [markdown]
# This shows that we have a good range of values for `userID` and `movieID`. Next, it is always a good idea to confirm the data format.

# %%
original_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55921681 entries, 0 to 55921680
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   ITEM_ID      object
#  1   USER_ID      int64
#  2   EVENT_VALUE  int64
#  3   TIMESTAMP    int64
# dtypes: int64(3), object(1)
# memory usage: 1.7+ GB

# %% [markdown]
# After manipulating the data, always confirm if the data format has changed.

# %% [markdown]
#  Amazon Personalize has default column names for users, items, and timestamp. These default column names are `USER_ID`, `ITEM_ID`, AND `TIMESTAMP`. So the final modification to the dataset is to replace the existing column headers with the default headers.

# %%
original_data['EVENT_TYPE'] = original_data.apply(lambda x: "rating", axis=1)

original_data.head()
# Out:
#       ITEM_ID  USER_ID  EVENT_VALUE   TIMESTAMP EVENT_TYPE
# 0  B00RP4XVFU  9979839            5  1424649600     rating
# 1  B00QFPEOQA  9979839            5  1424822400     rating
# 2  B0052P21K0  9979839            5  1424304000     rating
# 3  B00Q375GVC  9979839            5  1420243200     rating
# 4  B00TABYZX8  9979839            5  1424822400     rating

# %%
original_data.head()
# Out:
#       ITEM_ID  USER_ID  EVENT_VALUE   TIMESTAMP EVENT_TYPE
# 0  B00RP4XVFU  9979839            5  1424649600     rating
# 1  B00QFPEOQA  9979839            5  1424822400     rating
# 2  B0052P21K0  9979839            5  1424304000     rating
# 3  B00Q375GVC  9979839            5  1420243200     rating
# 4  B00TABYZX8  9979839            5  1424822400     rating

# %% [markdown]
# That's it! At this point the data is ready to go, and we just need to save it as a CSV file.

# %%
interactions_filename = "interactions.csv"
original_data.to_csv((data_dir+"/"+interactions_filename), index=False, float_format='%.0f')

# %% [markdown]
# ## Create dataset groups and the interactions dataset <a class="anchor" id="group_dataset"></a>
# [Back to top](#top)
#
# The highest level of isolation and abstraction with Amazon Personalize is a *dataset group*. Information stored within one of these dataset groups has no impact on any other dataset group or models created from one - they are completely isolated. This allows you to run many experiments and is part of how we keep your models private and fully trained only on your data.
#
# Before importing the data prepared earlier, there needs to be a dataset group and a dataset added to it that handles the interactions.
#
# Dataset groups can house the following types of information:
#
# * User-item-interactions
# * Event streams (real-time interactions)
# * User metadata
# * Item metadata
#
# Before we create the dataset group and the dataset for our interaction data, let's validate that your environment can communicate successfully with Amazon Personalize.

# %%
# Configure the SDK to Personalize:
personalize = boto3.client('personalize')
personalize_runtime = boto3.client('personalize-runtime')

# %% [markdown]
# ### Create the dataset group
#
# The following cell will create a new dataset group with the name `personalize-ranking-ml100k`.

# %%
create_dataset_group_response = personalize.create_dataset_group(
    name = "personalize-ranking-amz-review"
)

dataset_group_arn = create_dataset_group_response['datasetGroupArn']
print(json.dumps(create_dataset_group_response, indent=2))
# Out:
# {
#   "datasetGroupArn": "arn:aws:personalize:us-east-1:230755935769:dataset-group/personalize-ranking-amz-review",
#   "ResponseMetadata": {
#     "RequestId": "c39939ea-2ef4-4da2-a7d9-93cf85011057",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "content-type": "application/x-amz-json-1.1",
#       "date": "Sat, 12 Dec 2020 07:04:39 GMT",
#       "x-amzn-requestid": "c39939ea-2ef4-4da2-a7d9-93cf85011057",
#       "content-length": "109",
#       "connection": "keep-alive"
#     },
#     "RetryAttempts": 0
#   }
# }

# %% [markdown]
# Before we can use the dataset group, it must be active. This can take a minute or two. Execute the cell below and wait for it to show the ACTIVE status. It checks the status of the dataset group every second, up to a maximum of 3 hours.

# %%
max_time = time.time() + 3*60*60 # 3 hours
while time.time() < max_time:
    describe_dataset_group_response = personalize.describe_dataset_group(
        datasetGroupArn = dataset_group_arn
    )
    status = describe_dataset_group_response["datasetGroup"]["status"]
    print("DatasetGroup: {}".format(status))
    
    if status == "ACTIVE" or status == "CREATE FAILED":
        break
        
    time.sleep(60)
# Out:
# DatasetGroup: CREATE PENDING
# DatasetGroup: ACTIVE

# %% [markdown]
# Now that you have a dataset group, you can create a dataset for the interaction data.

# %% [markdown]
# ### Create the dataset
#
# First, define a schema to tell Amazon Personalize what type of dataset you are uploading. There are several reserved and mandatory keywords required in the schema, based on the type of dataset. More detailed information can be found in the [documentation](https://docs.aws.amazon.com/personalize/latest/dg/how-it-works-dataset-schema.html).
#
# Here, you will create a schema for interactions data, which needs the `USER_ID`, `ITEM_ID`, and `TIMESTAMP` fields. These must be defined in the same order in the schema as they appear in the dataset.

# %%
interactions_schema = {
    "type": "record",
    "name": "Interactions",
    "namespace": "com.amazonaws.personalize.schema",
    "fields": [
        {
            "name": "USER_ID",
            "type": "string"
        },
        {
            "name": "ITEM_ID",
            "type": "string"
        },
        {
          "name": "EVENT_VALUE",
          "type": [
             "float",
             "null"
          ]
        },
        {
            "name": "TIMESTAMP",
            "type": "long"
        },
        {
            "name": "EVENT_TYPE",
            "type": "string"
        },
    ],
    "version": "1.0"
}

create_schema_response = personalize.create_schema(
    name = "p13n-amz-review-ranking",
    schema = json.dumps(interactions_schema)
)

schema_arn = create_schema_response['schemaArn']
print(json.dumps(create_schema_response, indent=2))
# Out:
# {
#   "schemaArn": "arn:aws:personalize:us-east-1:230755935769:schema/p13n-amz-review-ranking",
#   "ResponseMetadata": {
#     "RequestId": "cad97703-2c9d-47da-a25d-3ea07060d2bc",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "content-type": "application/x-amz-json-1.1",
#       "date": "Sat, 12 Dec 2020 07:07:09 GMT",
#       "x-amzn-requestid": "cad97703-2c9d-47da-a25d-3ea07060d2bc",
#       "content-length": "89",
#       "connection": "keep-alive"
#     },
#     "RetryAttempts": 0
#   }
# }

# %% [markdown]
# With a schema created, you can create a dataset within the dataset group. Note, this does not load the data yet. This will happen a few steps later.

# %%
dataset_type = "INTERACTIONS"
create_dataset_response = personalize.create_dataset(
    name = "personalize-ranking-amz-review",
    datasetType = dataset_type,
    datasetGroupArn = dataset_group_arn,
    schemaArn = schema_arn
)

interactions_dataset_arn = create_dataset_response['datasetArn']
print(json.dumps(create_dataset_response, indent=2))
# Out:
# {
#   "datasetArn": "arn:aws:personalize:us-east-1:230755935769:dataset/personalize-ranking-amz-review/INTERACTIONS",
#   "ResponseMetadata": {
#     "RequestId": "120b507e-70dc-4643-9afd-a2731eb4b318",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "content-type": "application/x-amz-json-1.1",
#       "date": "Sat, 12 Dec 2020 07:07:51 GMT",
#       "x-amzn-requestid": "120b507e-70dc-4643-9afd-a2731eb4b318",
#       "content-length": "111",
#       "connection": "keep-alive"
#     },
#     "RetryAttempts": 0
#   }
# }

# %% [markdown]
# ## Configure an S3 bucket and an IAM  role <a class="anchor" id="bucket_role"></a>
# [Back to top](#top)
#
# So far, we have downloaded, manipulated, and saved the data onto the Amazon EBS instance attached to instance running this Jupyter notebook. However, Amazon Personalize will need an S3 bucket to act as the source of your data, as well as IAM roles for accessing that bucket. Let's set all of that up.
#
# Use the metadata stored on the instance underlying this Amazon SageMaker notebook, to determine the region it is operating in. If you are using a Jupyter notebook outside of Amazon SageMaker, simply define the region as a string below. The Amazon S3 bucket needs to be in the same region as the Amazon Personalize resources we have been creating so far.

# %%
with open('/opt/ml/metadata/resource-metadata.json') as notebook_info:
    data = json.load(notebook_info)
    resource_arn = data['ResourceArn']
    region = resource_arn.split(':')[3]
print(region)
# Out:
# us-east-1

# %% [markdown]
# Amazon S3 bucket names are globally unique. To create a unique bucket name, the code below will append the string `personalizepoc` to your AWS account number. Then it creates a bucket with this name in the region discovered in the previous cell.

# %%
s3 = boto3.client('s3')
suffix = str(np.random.uniform())[4:9]
bucket_name = "p13n-amz-review-ranking-demo-"+   suffix        # replace with the name of your S3 bucket
print(bucket_name)
if region != "us-east-1":
    s3.create_bucket(Bucket=bucket_name, CreateBucketConfiguration={'LocationConstraint': region})
else:
    s3.create_bucket(Bucket=bucket_name)
# Out:
# p13n-amz-review-ranking-demo-90409

# %% [markdown]
# ### Upload data to S3
#
# Now that your Amazon S3 bucket has been created, upload the CSV file of our user-item-interaction data.

# %%
interactions_file_path = data_dir  + interactions_filename
boto3.Session().resource('s3').Bucket(bucket_name).Object(interactions_filename).upload_file(interactions_file_path)
interactions_s3DataPath = "s3://"+bucket_name+"/"+interactions_filename
interactions_s3DataPath
# Out:
# 's3://p13n-amz-review-ranking-demo-90409/interactions.csv'

# %% [markdown]
# ### Set the S3 bucket policy
# Amazon Personalize needs to be able to read the contents of your S3 bucket. So add a bucket policy which allows that.

# %%
bucket_name
# Out:
# 'p13n-amz-review-ranking-demo-90409'

# %%
policy = {
    "Version": "2012-10-17",
    "Id": "PersonalizeS3BucketAccessPolicy",
    "Statement": [
        {
            "Sid": "PersonalizeS3BucketAccessPolicy",
            "Effect": "Allow",
            "Principal": {
                "Service": "personalize.amazonaws.com"
            },
            "Action": [
                "s3:*Object",
                "s3:ListBucket"
            ],
            "Resource": [
                "arn:aws:s3:::{}".format(bucket_name),
                "arn:aws:s3:::{}/*".format(bucket_name)
            ]
        }
    ]
}

s3.put_bucket_policy(Bucket=bucket_name, Policy=json.dumps(policy))
# Out:
# {'ResponseMetadata': {'RequestId': '265245A3115071D6',
#   'HostId': 'jaa1BpqTDWGoNGVvzXNJqy5Bv8+Qs1qIO828Xz6FawWQeFUhJaETUmZArWUtASne3xFTiNuP3MY=',
#   'HTTPStatusCode': 204,
#   'HTTPHeaders': {'x-amz-id-2': 'jaa1BpqTDWGoNGVvzXNJqy5Bv8+Qs1qIO828Xz6FawWQeFUhJaETUmZArWUtASne3xFTiNuP3MY=',
#    'x-amz-request-id': '265245A3115071D6',
#    'date': 'Sat, 12 Dec 2020 07:35:29 GMT',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Create an IAM role
#
# Amazon Personalize needs the ability to assume roles in AWS in order to have the permissions to execute certain tasks. Let's create an IAM role and attach the required policies to it. The code below attaches very permissive policies; please use more restrictive policies for any production application.

# %%
iam = boto3.client("iam")

role_name = "AmzReviewRankingRole"
assume_role_policy_document = {
    "Version": "2012-10-17",
    "Statement": [
        {
          "Effect": "Allow",
          "Principal": {
            "Service": "personalize.amazonaws.com"
          },
          "Action": "sts:AssumeRole"
        }
    ]
}

# create_role_response = iam.create_role(
#     RoleName = role_name,
#     AssumeRolePolicyDocument = json.dumps(assume_role_policy_document)
# )

# AmazonPersonalizeFullAccess provides access to any S3 bucket with a name that includes "personalize" or "Personalize" 
# if you would like to use a bucket with a different name, please consider creating and attaching a new policy
# that provides read access to your bucket or attaching the AmazonS3ReadOnlyAccess policy to the role
policy_arn = "arn:aws:iam::aws:policy/service-role/AmazonPersonalizeFullAccess"
iam.attach_role_policy(
    RoleName = role_name,
    PolicyArn = policy_arn
)

# Now add S3 support
iam.attach_role_policy(
    PolicyArn='arn:aws:iam::aws:policy/AmazonS3FullAccess',
    RoleName=role_name
)
time.sleep(60) # wait for a minute to allow IAM role policy attachment to propagate

role_arn = create_role_response["Role"]["Arn"]
print(role_arn)
# Out:
# arn:aws:iam::230755935769:role/AmzReviewRankingRole

# %%
role_arn="arn:aws:iam::230755935769:role/PersonalizeAmzRole"

# %% [markdown]
# ## Import the interactions data <a class="anchor" id="import"></a>
# [Back to top](#top)
#
# Earlier you created the dataset group and dataset to house your information, so now you will execute an import job that will load the data from the S3 bucket into the Amazon Personalize dataset.

# %%
"s3://{}/{}".format(bucket_name, interactions_filename)
# Out:
# 's3://p13n-amz-review-ranking-demo-29886/interactions.csv'

# %%
create_dataset_import_job_response = personalize.create_dataset_import_job(
    jobName = "p13n-amz-review-ranking-job-2",
    datasetArn = interactions_dataset_arn,
    dataSource = {
        "dataLocation": "s3://{}/{}".format(bucket_name, interactions_filename)
    },
    roleArn = role_arn
)

dataset_import_job_arn = create_dataset_import_job_response['datasetImportJobArn']
print(json.dumps(create_dataset_import_job_response, indent=2))
# Out:
# {
#   "datasetImportJobArn": "arn:aws:personalize:us-east-1:230755935769:dataset-import-job/p13n-amz-review-ranking-job-2",
#   "ResponseMetadata": {
#     "RequestId": "abc14468-311f-46fa-81d6-f6c0450aa56e",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "content-type": "application/x-amz-json-1.1",
#       "date": "Sat, 12 Dec 2020 07:36:06 GMT",
#       "x-amzn-requestid": "abc14468-311f-46fa-81d6-f6c0450aa56e",
#       "content-length": "117",
#       "connection": "keep-alive"
#     },
#     "RetryAttempts": 0
#   }
# }

# %% [markdown]
# Before we can use the dataset, the import job must be active. Execute the cell below and wait for it to show the ACTIVE status. It checks the status of the import job every second, up to a maximum of 3 hours.
#
# Importing the data can take some time, depending on the size of the dataset. In this workshop, the data import job should take around 15 minutes.

# %%
# %%time

max_time = time.time() + 3*60*60 # 3 hours
while time.time() < max_time:
    describe_dataset_import_job_response = personalize.describe_dataset_import_job(
        datasetImportJobArn = dataset_import_job_arn
    )
    status = describe_dataset_import_job_response["datasetImportJob"]['status']
    print("DatasetImportJob: {}".format(status))
    
    if status == "ACTIVE" or status == "CREATE FAILED":
        break
        
    time.sleep(60)
# Out:
# DatasetImportJob: ACTIVE
# CPU times: user 13.3 ms, sys: 350 µs, total: 13.6 ms
# Wall time: 1.07 s

# %% [markdown]
# When the dataset import is active, you are ready to start building models with SIMS, Personalized-Ranking, Popularity-Count, and HRNN. This process will continue in other notebooks. Run the cell below before moving on to store a few values for usage in the next notebooks.

# %% [markdown]
# ## Create solutions <a class="anchor" id="solutions"></a>
# [Back to top](#top)
#
# In this notebook, you will create solutions with the following recipe:
#
# `aws-personalized-ranking`

# %% [markdown]
# In Amazon Personalize, a specific variation of an algorithm is called a recipe. Different recipes are suitable for different situations. A trained model is called a solution, and each solution can have many versions that relate to a given volume of data when the model was trained.
#
# To start, we will list all the recipes that are supported. This will allow you to select one and use that to build your model.

# %%
personalize.list_recipes()
# Out:
# {'recipes': [{'name': 'aws-hrnn',
#    'recipeArn': 'arn:aws:personalize:::recipe/aws-hrnn',
#    'status': 'ACTIVE',
#    'creationDateTime': datetime.datetime(2019, 6, 10, 0, 0, tzinfo=tzlocal()),
#    'lastUpdatedDateTime': datetime.datetime(2020, 8, 25, 16, 57, 0, 148000, tzinfo=tzlocal())},
#   {'name': 'aws-hrnn-coldstart',
#    'recipeArn': 'arn:aws:personalize:::recipe/aws-hrnn-coldstart',
#    'status': 'ACTIVE',
#    'creationDateTime': datetime.datetime(2019, 6, 10, 0, 0, tzinfo=tzlocal()),
#    'lastUpdatedDateTime': datetime.datetime(2020, 8, 25, 16, 57, 0, 148000, tzinfo=tzlocal())},
#   {'name': 'aws-hrnn-metadata',
#    'recipeArn': 'arn:aws:personalize:::recipe/aws-hrnn-metadata',
#    'status': 'ACTIVE',
#    'creationDateTime': datetime.datetime(2019, 6, 10, 0, 0, tzinfo=tzlocal()),
#    'lastUpdatedDateTime': datetime.datetime(2020, 8, 25, 16, 57, 0, 148000, tzinfo=tzlocal())},
#   {'name': 'aws-personalized-ranking',
#    'recipeArn': 'arn:aws:personalize:::recipe/aws-personalized-ranking',
#    'status': 'ACTIVE',
#    'creationDateTime': datetime.datetime(2019, 6, 10, 0, 0, tzinfo=tzlocal()),
#    'lastUpdatedDateTime': datetime.datetime(2020, 8, 25, 16, 57, 0, 148000, tzinfo=tzlocal())},
#   {'name': 'aws-popularity-count',
#    'recipeArn': 'arn:aws:personalize:::recipe/aws-popularity-count',
#    'status': 'ACTIVE',
#    'creationDateTime': datetime.datetime(2019, 6, 10, 0, 0, tzinfo=tzlocal()),
#    'lastUpdatedDateTime': datetime.datetime(2020, 8, 25, 16, 57, 0, 148000, tzinfo=tzlocal())},
#   {'name': 'aws-sims',
#    'recipeArn': 'arn:aws:personalize:::recipe/aws-sims',
#    'status': 'ACTIVE',
#    'creationDateTime': datetime.datetime(2019, 6, 10, 0, 0, tzinfo=tzlocal()),
#    'lastUpdatedDateTime': datetime.datetime(2020, 8, 25, 16, 57, 0, 148000, tzinfo=tzlocal())},
#   {'name': 'aws-user-personalization',
#    'recipeArn': 'arn:aws:personalize:::recipe/aws-user-personalization',
#    'status': 'ACTIVE',
#    'creationDateTime': datetime.datetime(2019, 6, 10, 0, 0, tzinfo=tzlocal()),
#    'lastUpdatedDateTime': datetime.datetime(2020, 8, 25, 16, 57, 0, 148000, tzinfo=tzlocal())}],
#  'ResponseMetadata': {'RequestId': 'b913d4bb-8ea9-45b8-80d5-9249ef740c91',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#    'date': 'Sat, 12 Dec 2020 13:11:02 GMT',
#    'x-amzn-requestid': 'b913d4bb-8ea9-45b8-80d5-9249ef740c91',
#    'content-length': '1259',
#    'connection': 'keep-alive'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Personalized Ranking
#
# Personalized Ranking is an interesting application of HRNN. Instead of just recommending what is most probable for the user in question, this algorithm takes in a user and a list of items as well. The items are then rendered back in the order of most probable relevance for the user. The use case here is for filtering on genre for example, or when you have a broad collection that you would like better ordered for a particular user.

# %%
rerank_recipe_arn = "arn:aws:personalize:::recipe/aws-personalized-ranking"

# %% [markdown]
# #### Create the solution
#
# As with the previous solution, start by creating the solution first. Although you provide the dataset ARN in this step, the model is not yet trained. See this as an identifier instead of a trained model.

# %%
rerank_create_solution_response = personalize.create_solution(
    name = "p13n-amz-review-ranking",
    datasetGroupArn = dataset_group_arn,
    recipeArn = rerank_recipe_arn
)

rerank_solution_arn = rerank_create_solution_response['solutionArn']
print(json.dumps(rerank_create_solution_response, indent=2))
# Out:
# {
#   "solutionArn": "arn:aws:personalize:us-east-1:230755935769:solution/p13n-amz-review-ranking",
#   "ResponseMetadata": {
#     "RequestId": "689174d7-25f6-4698-8328-b5a7537f853c",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "content-type": "application/x-amz-json-1.1",
#       "date": "Sat, 12 Dec 2020 13:11:11 GMT",
#       "x-amzn-requestid": "689174d7-25f6-4698-8328-b5a7537f853c",
#       "content-length": "93",
#       "connection": "keep-alive"
#     },
#     "RetryAttempts": 0
#   }
# }

# %% [markdown]
# #### Create the solution version
#
# Once you have a solution, you need to create a version in order to complete the model training. The training can take a while to complete, upwards of 25 minutes, and an average of 35 minutes for this recipe with our dataset. Normally, we would use a while loop to poll until the task is completed. However the task would block other cells from executing, and the goal here is to create many models and deploy them quickly. So we will set up the while loop for all of the solutions further down in the notebook. There, you will also find instructions for viewing the progress in the AWS console.

# %%
rerank_create_solution_version_response = personalize.create_solution_version(
    solutionArn = rerank_solution_arn
)

# %%
rerank_solution_version_arn = rerank_create_solution_version_response['solutionVersionArn']
print(json.dumps(rerank_create_solution_version_response, indent=2))
# Out:
# {
#   "solutionVersionArn": "arn:aws:personalize:us-east-1:230755935769:solution/p13n-amz-review-ranking/04fe49a3",
#   "ResponseMetadata": {
#     "RequestId": "ff5358a5-38f5-4bec-afb1-4851e851532f",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "content-type": "application/x-amz-json-1.1",
#       "date": "Sat, 12 Dec 2020 13:11:17 GMT",
#       "x-amzn-requestid": "ff5358a5-38f5-4bec-afb1-4851e851532f",
#       "content-length": "109",
#       "connection": "keep-alive"
#     },
#     "RetryAttempts": 0
#   }
# }

# %% [markdown]
# ### View solution creation status
#
# As promised, how to view the status updates in the console:
#
# * In another browser tab you should already have the AWS Console up from opening this notebook instance.
# * Switch to that tab and search at the top for the service `Personalize`, then go to that service page.
# * Click `View dataset groups`.
# * Click the name of your dataset group, most likely something with POC in the name.
# * Click `Solutions and recipes`.
# * You will now see a list of all of the solutions you created above,  including a column with the status of the solution versions. Once it is `Active`, your solution is ready to be reviewed. It is also capable of being deployed.
#
# Or simply run the cell below to keep track of the solution version creation status.

# %%
in_progress_solution_versions = [
    rerank_solution_version_arn
]

max_time = time.time() + 3*60*60 # 3 hours
while time.time() < max_time:
    for solution_version_arn in in_progress_solution_versions:
        version_response = personalize.describe_solution_version(
            solutionVersionArn = solution_version_arn
        )
        status = version_response["solutionVersion"]["status"]
        
        if status == "ACTIVE":
            print("Build succeeded for {}".format(solution_version_arn))
            in_progress_solution_versions.remove(solution_version_arn)
        elif status == "CREATE FAILED":
            print("Build failed for {}".format(solution_version_arn))
            in_progress_solution_versions.remove(solution_version_arn)
    
    if len(in_progress_solution_versions) <= 0:
        break
    else:
        print("At least one solution build is still in progress")
        
    time.sleep(60)
# Out:
# Build succeeded for arn:aws:personalize:us-east-1:230755935769:solution/p13n-amz-review-ranking/04fe49a3

# %% [markdown]
# ## Create campaigns <a class="anchor" id="create"></a>
# [Back to top](#top)
#
# A campaign is a hosted solution version; an endpoint which you can query for recommendations. Pricing is set by estimating throughput capacity (requests from users for personalization per second). When deploying a campaign, you set a minimum throughput per second (TPS) value. This service, like many within AWS, will automatically scale based on demand, but if latency is critical, you may want to provision ahead for larger demand. For this POC and demo, all minimum throughput thresholds are set to 1. For more information, see the [pricing page](https://aws.amazon.com/personalize/pricing/).
#
# Let's start deploying the campaigns.

# %% [markdown]
# ### Personalized Ranking
#
# Deploy a campaign for your personalized ranking solution version. It can take around 10 minutes to deploy a campaign. Normally, we would use a while loop to poll until the task is completed. However the task would block other cells from executing, and the goal here is to create multiple campaigns. So we will set up the while loop for all of the campaigns further down in the notebook. There, you will also find instructions for viewing the progress in the AWS console.

# %%
rerank_create_campaign_response = personalize.create_campaign(
    name = "p13n-amz-review-poc-rerank",
    solutionVersionArn = rerank_solution_version_arn,
    minProvisionedTPS = 1
)

rerank_campaign_arn = rerank_create_campaign_response['campaignArn']
print(json.dumps(rerank_create_campaign_response, indent=2))
# Out:
# {
#   "campaignArn": "arn:aws:personalize:us-east-1:230755935769:campaign/p13n-amz-review-poc-rerank",
#   "ResponseMetadata": {
#     "RequestId": "b7a70e80-e0d8-43e1-9965-9a1bd85327b7",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "content-type": "application/x-amz-json-1.1",
#       "date": "Sun, 13 Dec 2020 12:48:13 GMT",
#       "x-amzn-requestid": "b7a70e80-e0d8-43e1-9965-9a1bd85327b7",
#       "content-length": "96",
#       "connection": "keep-alive"
#     },
#     "RetryAttempts": 0
#   }
# }

# %% [markdown]
# ### View campaign creation status
#
# As promised, how to view the status updates in the console:
#
# * In another browser tab you should already have the AWS Console up from opening this notebook instance.
# * Switch to that tab and search at the top for the service `Personalize`, then go to that service page.
# * Click `View dataset groups`.
# * Click the name of your dataset group, most likely something with POC in the name.
# * Click `Campaigns`.
# * You will now see a list of all of the campaigns you created above, including a column with the status of the campaign. Once it is `Active`, your campaign is ready to be queried.
#
# Or simply run the cell below to keep track of the campaign creation status.

# %%
in_progress_campaigns = [
    rerank_campaign_arn
]

max_time = time.time() + 3*60*60 # 3 hours
while time.time() < max_time:
    for campaign_arn in in_progress_campaigns:
        version_response = personalize.describe_campaign(
            campaignArn = campaign_arn
        )
        status = version_response["campaign"]["status"]
        
        if status == "ACTIVE":
            print("Build succeeded for {}".format(campaign_arn))
            in_progress_campaigns.remove(campaign_arn)
        elif status == "CREATE FAILED":
            print("Build failed for {}".format(campaign_arn))
            in_progress_campaigns.remove(campaign_arn)
    
    if len(in_progress_campaigns) <= 0:
        break
    else:
        print("At least one campaign build is still in progress")
        
    time.sleep(60)
# Out:
# At least one campaign build is still in progress
# At least one campaign build is still in progress
# At least one campaign build is still in progress
# At least one campaign build is still in progress
# At least one campaign build is still in progress
# At least one campaign build is still in progress
# At least one campaign build is still in progress
# At least one campaign build is still in progress
# At least one campaign build is still in progress
# Build succeeded for arn:aws:personalize:us-east-1:230755935769:campaign/p13n-amz-review-poc-rerank

# %%
## progress this afternoon

# %% [markdown]
# ## Interact with campaigns <a class="anchor" id="interact"></a>
# [Back to top](#top)
#
# Now that all campaigns are deployed and active, we can start to get recommendations via an API call. Each of the campaigns is based on a different recipe, which behave in slightly different ways because they serve different use cases. We will cover each campaign in a different order than used in previous notebooks, in order to deal with the possible complexities in ascending order (i.e. simplest first).
#
# First, let's create a supporting function to help make sense of the results returned by a Personalize campaign. Personalize returns only an `item_id`. This is great for keeping data compact, but it means you need to query a database or lookup table to get a human-readable result for the notebooks. We will create a helper function to return a human-readable result from the MovieLens dataset.
#
# Start by loading in the dataset which we can use for our lookup table.

# %%
items_df = pd.read_csv('product.csv')
items_df = items_df.reset_index()

# %%
c_row = items_df[items_df['product_id']== "B000CO7WPK"].iloc[0] 
title = c_row['product_title'] 
category = c_row['product_category'] 
(title, category) 
# items_df.head()
# Out:
# ('KYB 344055 Excel-G Gas Shock', 'Automotive')

# %%
def get_product_by_id(product_id, items_df):
    """
    This takes in an movie_id from Personalize so it will be a string,
    converts it to an int, and then does a lookup in a default or specified
    dataframe.
    
    A really broad try/except clause was added in case anything goes wrong.
    
    Feel free to add more debugging or filtering here to improve results if
    you hit an error.
    """
    try:
        c_row = items_df[items_df['product_id']==product_id].iloc[0]
        title = c_row['product_title'] 
        category = c_row['product_category'] 

        return [title, category]
    except:
        return "Error obtaining product info"

# %% [markdown]
# Now let's test a few simple values to check our error catching.

# %%
# A known good id
print(get_product_by_id(product_id="B00KKEI8ZA", items_df=items_df))
# Out:
# Error obtaining movie info

# %% [markdown]
# Great! Now we have a way of rendering results.

# %% [markdown]
# ### Personalized Ranking
#
# The core use case for personalized ranking is to take a collection of items and to render them in priority or probable order of interest for a user. To demonstrate this, we will need a random user and a random collection of 25 items.

# %%
master_user="master_user"
master_user_password="master_user_password"
elastic_search_endpoint="elastic_search_endpoint"

# %%
import requests 

r = requests.get('https://{}/product/product/_search?q=product_title:coach&size=100'.format(elastic_search_endpoint), auth=(master_user, master_user_password))
rjson = r.json()
rjson
# Out:
# {'took': 4740,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4095, 'relation': 'eq'},
#   'max_score': 12.69479,
#   'hits': [{'_index': 'product',
#     '_type': 'product',
#     '_id': 'xz6EUnYB7ZcjQTgaLI97',
#     '_score': 12.69479,
#     '_source': {'product_id': 'B005DSNBI2',
#      'product_category': 'Beauty',
#      'product_title': 'COACH SIGNATURE by Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'qeq-UXYB1EYWinhndsNC',
#     '_score': 12.205915,
#     '_source': {'product_id': '6305826811',
#      'product_category': 'Video_DVD',
#      'product_title': 'Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '9gilUXYBXrWQULoffXeG',
#     '_score': 12.205915,
#     '_source': {'product_id': '6305826811',
#      'product_category': 'Video_DVD',
#      'product_title': 'Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'lGBsXnYB7ZcjQTga_h6T',
#     '_score': 12.205915,
#     '_source': {'product_id': 'B003QF6W8U',
#      'product_category': 'Digital_Video_Download',
#      'product_title': 'Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '6kh1VXYB7ZcjQTgaA9YV',
#     '_score': 12.1975,
#     '_source': {'product_id': 'B003QFFO7K',
#      'product_category': 'Digital_Video_Download',
#      'product_title': 'Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'Kf-aVnYB1EYWinhn2dyZ',
#     '_score': 12.1975,
#     '_source': {'product_id': 'B009G6IPV0',
#      'product_category': 'Digital_Ebook_Purchase',
#      'product_title': 'Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'O1TTWXYB7ZcjQTgaBi02',
#     '_score': 12.1975,
#     '_source': {'product_id': 'B003CRM6RI',
#      'product_category': 'Video_DVD',
#      'product_title': 'Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '2Qm1UXYBXrWQULof7RBa',
#     '_score': 12.15854,
#     '_source': {'product_id': '6305826811',
#      'product_category': 'Video_DVD',
#      'product_title': 'Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'QdoJVHYBWQlvJU18jKdU',
#     '_score': 12.15854,
#     '_source': {'product_id': 'B001KLT018',
#      'product_category': 'Apparel',
#      'product_title': 'Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '3AjQWXYB1EYWinhnezCp',
#     '_score': 12.15854,
#     '_source': {'product_id': 'B003QFC5GS',
#      'product_category': 'Digital_Video_Download',
#      'product_title': 'Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'hUubVnYB7ZcjQTgayNTb',
#     '_score': 12.12673,
#     '_source': {'product_id': 'B008Y5QPQG',
#      'product_category': 'Digital_Video_Download',
#      'product_title': 'Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'Lu6fW3YBWQlvJU189Vsx',
#     '_score': 12.12673,
#     '_source': {'product_id': '2843234271',
#      'product_category': 'Books',
#      'product_title': 'Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'CRXhXnYB1EYWinhnQVem',
#     '_score': 11.915868,
#     '_source': {'product_id': 'B00BZ9P334',
#      'product_category': 'Shoes',
#      'product_title': 'Coach COACH 22418M-SVB8F Coach  Hamptons Weekend Hippie Crossbody                Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'zPTBUnYB1EYWinhnN_Pk',
#     '_score': 11.845661,
#     '_source': {'product_id': 'B009VD4WDI',
#      'product_category': 'Beauty',
#      'product_title': 'COACH House of Coach Coffret Set'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'bvSxUnYB1EYWinhnUFYM',
#     '_score': 11.836937,
#     '_source': {'product_id': '076454313X',
#      'product_category': 'Books',
#      'product_title': 'Kitchen Coach: Weekend Cooking (Kitchen Coach)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'ogLJV3YB1EYWinhnR-3I',
#     '_score': 11.836937,
#     '_source': {'product_id': 'B00EGI6JHK',
#      'product_category': 'Video_DVD',
#      'product_title': 'COACH CARTER (WS) COACH CARTER (WS)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '9PYEU3YB1EYWinhnrYuv',
#     '_score': 11.767645,
#     '_source': {'product_id': 'B003NR7WYO',
#      'product_category': 'Beauty',
#      'product_title': 'Coach Legacy By Coach For Women'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'RtfXUnYBWQlvJU189k9c',
#     '_score': 11.4623165,
#     '_source': {'product_id': 'B00ATA7DQA',
#      'product_category': 'Beauty',
#      'product_title': 'Coach Love Perfume By Coach For Women'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '4hfOX3YB1EYWinhnUr5s',
#     '_score': 11.437118,
#     '_source': {'product_id': 'B000L6VWF0',
#      'product_category': 'Shoes',
#      'product_title': 'Coach Handbags, Coach Signature Lunch Tote (Black)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'c98NVnYBWQlvJU18e-Ou',
#     '_score': 11.419146,
#     '_source': {'product_id': 'B00M10BS1M',
#      'product_category': 'Shoes',
#      'product_title': 'Coach Coach Legacy Leather Rory Satchel 19892'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'OezwUXYB1EYWinhnVLWy',
#     '_score': 11.4189,
#     '_source': {'product_id': 'B005C3QGYO',
#      'product_category': 'Sports',
#      'product_title': 'Coach Stopwatch'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'Tu4mUnYB1EYWinhn3tm4',
#     '_score': 11.4189,
#     '_source': {'product_id': 'B000E0W3OW',
#      'product_category': 'Video_DVD',
#      'product_title': 'Coach Carter'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '-tSaUnYBWQlvJU18FumH',
#     '_score': 11.4189,
#     '_source': {'product_id': 'B0006NAB8W',
#      'product_category': 'Software',
#      'product_title': 'Singing Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'd9mWU3YBWQlvJU18wX3u',
#     '_score': 11.4189,
#     '_source': {'product_id': 'B00478ED36',
#      'product_category': 'Video_DVD',
#      'product_title': 'College Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'pVvVXHYB7ZcjQTgaOvz-',
#     '_score': 11.4189,
#     '_source': {'product_id': 'B0064ZEK8I',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Coach Nick'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'U11FXXYB7ZcjQTgaUh9t',
#     '_score': 11.4189,
#     '_source': {'product_id': 'B00NBIQMJG',
#      'product_category': 'Sports',
#      'product_title': 'Coach & Earring'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'RxL2XXYB1EYWinhnVvU0',
#     '_score': 11.4189,
#     '_source': {'product_id': 'B00AEFXOKO',
#      'product_category': 'Video_DVD',
#      'product_title': 'Coach Carter'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'R0LpUnYB7ZcjQTgaEjo0',
#     '_score': 11.410783,
#     '_source': {'product_id': 'B000HZEE64',
#      'product_category': 'Digital_Video_Download',
#      'product_title': 'Coach Carter'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'fFIxWXYB7ZcjQTgasopq',
#     '_score': 11.410783,
#     '_source': {'product_id': 'B003VNHF7E',
#      'product_category': 'Health_&_Personal_Care',
#      'product_title': 'COACH S2005'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'a83cUXYBWQlvJU18mF4O',
#     '_score': 11.394129,
#     '_source': {'product_id': 'B00H2GQ2W0',
#      'product_category': 'Mobile_Apps',
#      'product_title': 'Coach Me'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'l-35UXYB1EYWinhnpBM8',
#     '_score': 11.394129,
#     '_source': {'product_id': 'B0039GZI3G',
#      'product_category': 'Books',
#      'product_title': 'Stage-coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'i_sHVXYB1EYWinhnI8Oj',
#     '_score': 11.394129,
#     '_source': {'product_id': 'B0056JJ1M8',
#      'product_category': 'Digital_Video_Download',
#      'product_title': 'Coach Carter'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'geULWHYBWQlvJU183hDm',
#     '_score': 11.394129,
#     '_source': {'product_id': 'B009Z5Y3YK',
#      'product_category': 'Digital_Ebook_Purchase',
#      'product_title': 'Comeback Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '6BebX3YB1EYWinhnfDov',
#     '_score': 11.394129,
#     '_source': {'product_id': '1312949813',
#      'product_category': 'Books',
#      'product_title': 'Failure Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'H-S5V3YBWQlvJU18zzyX',
#     '_score': 11.37508,
#     '_source': {'product_id': '6305826765',
#      'product_category': 'Video',
#      'product_title': 'Coach [VHS]'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'ngYiWXYB1EYWinhnSmx7',
#     '_score': 11.37508,
#     '_source': {'product_id': '1888478020',
#      'product_category': 'Books',
#      'product_title': 'Wanted:Rowing Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '4wrPWnYB1EYWinhnrMeF',
#     '_score': 11.37508,
#     '_source': {'product_id': 'B0077QT3QC',
#      'product_category': 'Toys',
#      'product_title': 'City Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'g_nLX3YBWQlvJU18BSx-',
#     '_score': 11.37508,
#     '_source': {'product_id': 'B000A7DMSA',
#      'product_category': 'Video_DVD',
#      'product_title': 'Coach Carter'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'kUHLUnYB7ZcjQTga6FPl',
#     '_score': 11.344307,
#     '_source': {'product_id': 'B005MEZRDO',
#      'product_category': 'Health_&_Personal_Care',
#      'product_title': 'COACH S2001'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'AkLeUnYB7ZcjQTgadRTc',
#     '_score': 11.344307,
#     '_source': {'product_id': 'B005MEZFH2',
#      'product_category': 'Health_&_Personal_Care',
#      'product_title': 'COACH S2022'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '3fphVHYB1EYWinhnexRb',
#     '_score': 11.344307,
#     '_source': {'product_id': 'B005526Z0C',
#      'product_category': 'Mobile_Apps',
#      'product_title': 'Ear Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'wN5hVXYBWQlvJU18EyNf',
#     '_score': 11.344307,
#     '_source': {'product_id': 'B00AFYH004',
#      'product_category': 'Apparel',
#      'product_title': 'Coach Keychain'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'N_3FVXYB1EYWinhnMrFF',
#     '_score': 11.344307,
#     '_source': {'product_id': 'B00G6HW8II',
#      'product_category': 'Mobile_Apps',
#      'product_title': 'Language Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'hv4UVnYB1EYWinhnmH-X',
#     '_score': 11.344307,
#     '_source': {'product_id': 'B008P3SPVU',
#      'product_category': 'Digital_Video_Download',
#      'product_title': 'Coach Carter'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'XWQuYHYB7ZcjQTgaq65f',
#     '_score': 11.344307,
#     '_source': {'product_id': 'B00FYNK4XQ',
#      'product_category': 'Digital_Video_Download',
#      'product_title': 'COACH CARTER'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'AvQuXnYBWQlvJU18vv7e',
#     '_score': 11.103004,
#     '_source': {'product_id': 'B005G7QJRK',
#      'product_category': 'Beauty',
#      'product_title': 'Coach Poppy Flower Perfume By Coach For Women'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '6AsSW3YB1EYWinhnAnMh',
#     '_score': 11.094627,
#     '_source': {'product_id': 'B00H5WUFD8',
#      'product_category': 'Beauty',
#      'product_title': 'COACH POPPY by Coach BODY LOTION 5 OZ'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '0vQgXnYBWQlvJU18adjw',
#     '_score': 11.094627,
#     '_source': {'product_id': 'B004W1YGC6',
#      'product_category': 'Beauty',
#      'product_title': 'Coach Perfume by Coach for women Personal Fragrances'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'EvlNVHYB1EYWinhn6uL4',
#     '_score': 11.078515,
#     '_source': {'product_id': 'B005EM8FSI',
#      'product_category': 'Beauty',
#      'product_title': 'Coach Poppy Flower Perfume By Coach For Women'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'DUhoVXYB7ZcjQTgaYLZL',
#     '_score': 11.078515,
#     '_source': {'product_id': 'B00HVM5TUQ',
#      'product_category': 'Beauty',
#      'product_title': 'Coach Poppy Wildflower Perfume By Coach For Women'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'ofisX3YBWQlvJU18kN1T',
#     '_score': 11.061383,
#     '_source': {'product_id': 'B00DVKV42E',
#      'product_category': 'Video_DVD',
#      'product_title': 'COACH CARTER (DVD/WS) COACH CARTER (DVD/WS)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'ZRL2XXYB1EYWinhnxvZ7',
#     '_score': 11.029463,
#     '_source': {'product_id': 'B004BCX4TC',
#      'product_category': 'Beauty',
#      'product_title': 'Coach Perfume by Coach for women Personal Fragrances'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'aTxdUnYB7ZcjQTgaT_xA',
#     '_score': 10.770027,
#     '_source': {'product_id': 'B00FNO0M9W',
#      'product_category': 'Beauty',
#      'product_title': 'Coach 2 x 0.17 oz Eau de Parfum Dual Rollerball Coach Poppy / Coach Poppy Blossom'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'tUhQVXYB7ZcjQTgauXjL',
#     '_score': 10.757324,
#     '_source': {'product_id': 'B004JZIVBC',
#      'product_category': 'Beauty',
#      'product_title': 'Coach Poppy Perfume by Coach for women Personal Fragrances'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '1E6yV3YB7ZcjQTgaT6c7',
#     '_score': 10.757324,
#     '_source': {'product_id': 'B001OO0FJW',
#      'product_category': 'Watches',
#      'product_title': "Coach Watches- Coach Lexington All Stainless Steel Women's Watch"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'gBUSX3YB1EYWinhnpNd6',
#     '_score': 10.741716,
#     '_source': {'product_id': 'B00HZ5JYVE',
#      'product_category': 'Beauty',
#      'product_title': 'Coach Eau de Parfum Spray, Coach Love, 1.7 Ounce'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'yzfTUXYB7ZcjQTgaXoFp',
#     '_score': 10.727228,
#     '_source': {'product_id': 'B008Z5LJKW',
#      'product_category': 'Mobile_Apps',
#      'product_title': 'Sight Words Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'YNJcUnYBWQlvJU18vHet',
#     '_score': 10.727228,
#     '_source': {'product_id': 'B000E1B2SO',
#      'product_category': 'Video_Games',
#      'product_title': 'NFL Head Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'ufYvU3YB1EYWinhnD_lV',
#     '_score': 10.727228,
#     '_source': {'product_id': 'B00HER9REW',
#      'product_category': 'Shoes',
#      'product_title': 'Coach Peyton Cora'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '2_w3VXYB1EYWinhnxkHM',
#     '_score': 10.727228,
#     '_source': {'product_id': 'B00793IK4E',
#      'product_category': 'Shoes',
#      'product_title': 'Coach Vinni Boot'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '3908VXYBWQlvJU18-cU7',
#     '_score': 10.727228,
#     '_source': {'product_id': 'B00LFVPQIE',
#      'product_category': 'Shoes',
#      'product_title': 'Coach Peyton Cora'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'Z_BIXHYBWQlvJU18sRGc',
#     '_score': 10.727228,
#     '_source': {'product_id': 'B00X0435VO',
#      'product_category': 'Digital_Ebook_Purchase',
#      'product_title': 'Life Coach Tarot'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'QfJSXXYBWQlvJU18dsL_',
#     '_score': 10.727228,
#     '_source': {'product_id': 'B00BRJ6FQQ',
#      'product_category': 'Luggage',
#      'product_title': 'Coach Sis Tote'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'EBF3XXYB1EYWinhnNau9',
#     '_score': 10.727228,
#     '_source': {'product_id': 'B00CBSEMOE',
#      'product_category': 'Watches',
#      'product_title': 'Coach Madison Watch'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'whgzYHYB1EYWinhnscXB',
#     '_score': 10.727228,
#     '_source': {'product_id': 'B00A56CR28',
#      'product_category': 'Digital_Ebook_Purchase',
#      'product_title': 'The Timeshare Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '_wW9WHYB1EYWinhne2a6',
#     '_score': 10.725357,
#     '_source': {'product_id': 'B004BCZ0TY',
#      'product_category': 'Beauty',
#      'product_title': 'Coach Poppy Perfume by Coach for women Personal Fragrances'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'c_itX3YBWQlvJU18puAu',
#     '_score': 10.725357,
#     '_source': {'product_id': 'B004HHF2HI',
#      'product_category': 'Shoes',
#      'product_title': 'Coach Ashley Black Leather Satchel F15445 Bag - Coach 15445BK'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '9TkAUnYB7ZcjQTgatFMx',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B004HA6DQE',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Coach Bill McCartney'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'UTkMUnYB7ZcjQTgans_y',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B00EDXZ12M',
#      'product_category': 'Shoes',
#      'product_title': 'Coach Park Hobo'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'kvFeUnYB1EYWinhnCg17',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B0082OKDJO',
#      'product_category': 'Digital_Ebook_Purchase',
#      'product_title': 'The Coach House'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '5fFyUnYB1EYWinhnoN-5',
#     '_score': 10.7194,
#     '_source': {'product_id': '1467946516',
#      'product_category': 'Books',
#      'product_title': 'The Coach House'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'JdWnUnYBWQlvJU180XQt',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B00HJFMQUG',
#      'product_category': 'Shoes',
#      'product_title': 'Coach Park Hobo'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '9UIGU3YB7ZcjQTgaP4Ur',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B000ME3M5O',
#      'product_category': 'Video_Games',
#      'product_title': 'My Word Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'J9rQU3YBWQlvJU18BhKg',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B000CSUL2M',
#      'product_category': 'Video_Games',
#      'product_title': 'NFL Head Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'Pt6XVXYBWQlvJU18krGn',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B00DLU5QSM',
#      'product_category': 'Mobile_Apps',
#      'product_title': 'L4D - Coach Soundboard'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '1Et1VnYB7ZcjQTgaZ3AL',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B00EWNFFII',
#      'product_category': 'Digital_Ebook_Purchase',
#      'product_title': 'Low Carb Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '5k0lV3YB7ZcjQTgaWznb',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B00IVV2MGU',
#      'product_category': 'Office_Products',
#      'product_title': 'Coach Lanyard Blue'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '-01SV3YB7ZcjQTgaIK3l',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B00K5NPARA',
#      'product_category': 'Shoes',
#      'product_title': 'COACH Womens Talia'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '5AFpV3YB1EYWinhn6_UE',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B005EHAKOK',
#      'product_category': 'Mobile_Apps',
#      'product_title': 'Coach English Lite'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'TwXBWHYB1EYWinhn1nLP',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B00GZL0W7Y',
#      'product_category': 'Shoes',
#      'product_title': 'Coach Peyton Cora'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'wVIMWXYB7ZcjQTgadSm4',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B00JYIH97G',
#      'product_category': 'Shoes',
#      'product_title': 'COACH Womens 0HC8084'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '-OcUWXYBWQlvJU18z7-1',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B00QVPW1T6',
#      'product_category': 'Shoes',
#      'product_title': 'Coach Shoulder Handbag'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'WggBWnYB1EYWinhnq7B5',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B00B5O55VY',
#      'product_category': 'Mobile_Apps',
#      'product_title': 'Chinese Mandarin Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '-AspW3YB1EYWinhngLBx',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B00SFOI0WI',
#      'product_category': 'Shoes',
#      'product_title': 'COACH Womens 0HC7045'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'q2ClXnYB7ZcjQTgamrHC',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B004ES6TBS',
#      'product_category': 'Video_DVD',
#      'product_title': 'Coach: Season 4'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'efbfXnYBWQlvJU18Vcju',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B00AYJ0UEI',
#      'product_category': 'Digital_Ebook_Purchase',
#      'product_title': 'The Life Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'xhXqXnYB1EYWinhnW26l',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B00O0BV3RY',
#      'product_category': 'Digital_Ebook_Purchase',
#      'product_title': 'Coach Like Pop'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'rWPcX3YB7ZcjQTgaOtj2',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B00GNM6AQW',
#      'product_category': 'Shoes',
#      'product_title': 'Coach Peyton Convertible'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'FfnnX3YBWQlvJU18yXdC',
#     '_score': 10.7194,
#     '_source': {'product_id': 'B00793EL74',
#      'product_category': 'Shoes',
#      'product_title': 'Coach Vinni Boot'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'wj1xUnYB7ZcjQTgawswh',
#     '_score': 10.703789,
#     '_source': {'product_id': 'B005EV3CRS',
#      'product_category': 'Toys',
#      'product_title': 'Wedding Coach Theme'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'J_KDUnYB1EYWinhn65dg',
#     '_score': 10.703789,
#     '_source': {'product_id': 'B00965EJ02',
#      'product_category': 'Mobile_Apps',
#      'product_title': 'My Diet Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'X9fvUnYBWQlvJU181syy',
#     '_score': 10.703789,
#     '_source': {'product_id': 'B000CSUL36',
#      'product_category': 'Video_Games',
#      'product_title': 'NFL Head Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'X_vXVHYB1EYWinhnyEi8',
#     '_score': 10.703789,
#     '_source': {'product_id': 'B014C5K1Q6',
#      'product_category': 'Digital_Ebook_Purchase',
#      'product_title': 'CEO Strength Coach'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'XN0bVXYBWQlvJU18UW4I',
#     '_score': 10.703789,
#     '_source': {'product_id': 'B00OZY9WR4',
#      'product_category': 'Shoes',
#      'product_title': "COACH Women's Tristee"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'p9_uVXYBWQlvJU18BJGL',
#     '_score': 10.703789,
#     '_source': {'product_id': 'B000F8O2MO',
#      'product_category': 'Video_DVD',
#      'product_title': 'Coach: Season 1'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'JwD0VnYB1EYWinhnFcT9',
#     '_score': 10.703789,
#     '_source': {'product_id': 'B00O3V6T8Y',
#      'product_category': 'Shoes',
#      'product_title': 'Coach Peyton Cora'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'blhgW3YB7ZcjQTgaVzUt',
#     '_score': 10.703789,
#     '_source': {'product_id': 'B000BCGFDS',
#      'product_category': 'Software',
#      'product_title': 'Singing Coach Kidz'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'ThDmXHYB1EYWinhnwjSh',
#     '_score': 10.703789,
#     '_source': {'product_id': 'B006XND3NO',
#      'product_category': 'Digital_Ebook_Purchase',
#      'product_title': "The Cheerleader's Coach"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'P83YUXYBWQlvJU18aDOr',
#     '_score': 10.694045,
#     '_source': {'product_id': 'B0045SU5ZI',
#      'product_category': 'Beauty',
#      'product_title': 'Coach Poppy Perfume by Coach for women Personal Fragrances'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'yfKMUnYB1EYWinhnaOqn',
#     '_score': 10.694045,
#     '_source': {'product_id': 'B001OO4EB2',
#      'product_category': 'Watches',
#      'product_title': "Coach Watches- Coach Legacy with Signature Strap Women's Watch"}}]}}

# %%
items_from_search = [] 
for h in rjson['hits']['hits']:
    items_from_search.append(h['_source']['product_id'])

rerank_user = 9979839

# %% [markdown]
# Now build a nice dataframe that shows the input data.

# %%
rerank_list = []
for item in items_from_search:
    movie = get_product_by_id(item, items_df)

    rerank_list.append(movie)
rerank_df = pd.DataFrame(rerank_list)
rerank_df
# Out:
#                                                                  0  \
# 0   COACH SIGNATURE by Coach
# 1   Coach
# 2   Coach
# 3   Coach
# 4   Coach
# ..    ...
# 95  Coach Peyton Cora
# 96  Singing Coach Kidz
# 97  The Cheerleader's Coach
# 98  Coach Poppy Perfume by Coach for women Personal Fragrances
# 99  Coach Watches- Coach Legacy with Signature Strap Women's Watch
#
#                          1
# 0   Beauty
# 1   Video_DVD
# 2   Video_DVD
# 3   Digital_Video_Download
# 4   Digital_Video_Download
# ..                     ...
# 95  Shoes
# 96  Software
# 97  Digital_Ebook_Purchase
# 98  Beauty
# 99  Watches
#
# [100 rows x 2 columns]

# %% [markdown]
# Then make the personalized ranking API call.

# %%
import json

import numpy 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd





def plot_heat_map(df, figsize=(10,7)): 
    df = df.groupby(['product_category']).count()
    df = df.drop(['USER_ID', 'EVENT_VALUE', 'index'], axis=1)
    plt.subplots(figsize=figsize)
    sns.heatmap(df)




tester_df = original_data[original_data['USER_ID']==rerank_user]
all_df = tester_df.merge(items_df, left_on='ITEM_ID', right_on='product_id')
plot_heat_map(all_df, figsize=(10,5))
all_df.head()
# review = tester_df[['positive']+genres].groupby(['positive']).sum()
# plot_heat_map(review, figsize=(10,5))
# Out:
#       ITEM_ID  USER_ID  EVENT_VALUE   TIMESTAMP EVENT_TYPE    index  \
# 0  B00RP4XVFU  9979839  5            1424649600  rating     245005
# 1  B00QFPEOQA  9979839  5            1424822400  rating     440043
# 2  B0052P21K0  9979839  5            1424304000  rating     1875939
# 3  B00Q375GVC  9979839  5            1420243200  rating     2574926
# 4  B00TABYZX8  9979839  5            1424822400  rating     431806
#
#    product_id        product_category  \
# 0  B00RP4XVFU  Digital_Ebook_Purchase
# 1  B00QFPEOQA  Health_&_Personal_Care
# 2  B0052P21K0  Home_Improvement
# 3  B00Q375GVC  Health_&_Personal_Care
# 4  B00TABYZX8  Wireless
#
#                                                                                                                                                                              product_title
# 0  The Vanished--A Suspense Novel
# 1  SOMNIS - Natural Sleep Aid - Safe, Effective, Non-Habit Forming Supplement. Extra Strength Sleeping Pills Made with Melatonin, Gaba, and L-Tryptophan - 60 Capsules
# 2  Eureka 30" European Style Stainless Steel Island Mount Range Vent Hood
# 3  Nexgen Biolabs Oxislim Super Antioxidant and Fat Burner, 60 Count
# 4  Pamalo Easy Installable Car Phone Mount, Good for iPhone 6/5s/5c/4s/4, Samsung Galaxy S5/S4, Amazon Fire Phone, HTC One: Windshield Dashboard Car Mount Holder, Great Cell Phone Cradle

# %%
# Convert user to string:

rerank_item_list = []
for item in items_from_search:
    rerank_item_list.append(str(item))
    
# Get recommended reranking
get_recommendations_response_rerank = personalize_runtime.get_personalized_ranking(
        campaignArn = rerank_campaign_arn,
        userId = str(rerank_user),
        inputList = rerank_item_list
)

get_recommendations_response_rerank
# Out:
# {'ResponseMetadata': {'RequestId': 'd3ecd757-89c4-4bcf-bdbf-36c52770c84e',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/json',
#    'date': 'Mon, 14 Dec 2020 08:26:30 GMT',
#    'x-amzn-requestid': 'd3ecd757-89c4-4bcf-bdbf-36c52770c84e',
#    'content-length': '5737',
#    'connection': 'keep-alive'},
#   'RetryAttempts': 0},
#  'personalizedRanking': [{'itemId': 'B00G6HW8II', 'score': 0.4460057},
#   {'itemId': 'B00AEFXOKO', 'score': 0.0832643},
#   {'itemId': 'B005EM8FSI', 'score': 0.0765874},
#   {'itemId': 'B004ES6TBS', 'score': 0.0724244},
#   {'itemId': 'B0045SU5ZI', 'score': 0.0662087},
#   {'itemId': 'B004BCX4TC', 'score': 0.0590719},
#   {'itemId': 'B004BCZ0TY', 'score': 0.0565927},
#   {'itemId': 'B00965EJ02', 'score': 0.0563808},
#   {'itemId': 'B003NR7WYO', 'score': 0.0527986},
#   {'itemId': 'B0082OKDJO', 'score': 0.0306654},
#   {'itemId': 'B005DSNBI2'},
#   {'itemId': '6305826811'},
#   {'itemId': '6305826811'},
#   {'itemId': 'B003QF6W8U'},
#   {'itemId': 'B003QFFO7K'},
#   {'itemId': 'B009G6IPV0'},
#   {'itemId': 'B003CRM6RI'},
#   {'itemId': '6305826811'},
#   {'itemId': 'B001KLT018'},
#   {'itemId': 'B003QFC5GS'},
#   {'itemId': 'B008Y5QPQG'},
#   {'itemId': '2843234271'},
#   {'itemId': 'B00BZ9P334'},
#   {'itemId': 'B009VD4WDI'},
#   {'itemId': '076454313X'},
#   {'itemId': 'B00EGI6JHK'},
#   {'itemId': 'B00ATA7DQA'},
#   {'itemId': 'B000L6VWF0'},
#   {'itemId': 'B00M10BS1M'},
#   {'itemId': 'B005C3QGYO'},
#   {'itemId': 'B000E0W3OW'},
#   {'itemId': 'B0006NAB8W'},
#   {'itemId': 'B00478ED36'},
#   {'itemId': 'B0064ZEK8I'},
#   {'itemId': 'B00NBIQMJG'},
#   {'itemId': 'B000HZEE64'},
#   {'itemId': 'B003VNHF7E'},
#   {'itemId': 'B00H2GQ2W0'},
#   {'itemId': 'B0039GZI3G'},
#   {'itemId': 'B0056JJ1M8'},
#   {'itemId': 'B009Z5Y3YK'},
#   {'itemId': '1312949813'},
#   {'itemId': '6305826765'},
#   {'itemId': '1888478020'},
#   {'itemId': 'B0077QT3QC'},
#   {'itemId': 'B000A7DMSA'},
#   {'itemId': 'B005MEZRDO'},
#   {'itemId': 'B005MEZFH2'},
#   {'itemId': 'B005526Z0C'},
#   {'itemId': 'B00AFYH004'},
#   {'itemId': 'B008P3SPVU'},
#   {'itemId': 'B00FYNK4XQ'},
#   {'itemId': 'B005G7QJRK'},
#   {'itemId': 'B00H5WUFD8'},
#   {'itemId': 'B004W1YGC6'},
#   {'itemId': 'B00HVM5TUQ'},
#   {'itemId': 'B00DVKV42E'},
#   {'itemId': 'B00FNO0M9W'},
#   {'itemId': 'B004JZIVBC'},
#   {'itemId': 'B001OO0FJW'},
#   {'itemId': 'B00HZ5JYVE'},
#   {'itemId': 'B008Z5LJKW'},
#   {'itemId': 'B000E1B2SO'},
#   {'itemId': 'B00HER9REW'},
#   {'itemId': 'B00793IK4E'},
#   {'itemId': 'B00LFVPQIE'},
#   {'itemId': 'B00X0435VO'},
#   {'itemId': 'B00BRJ6FQQ'},
#   {'itemId': 'B00CBSEMOE'},
#   {'itemId': 'B00A56CR28'},
#   {'itemId': 'B004HHF2HI'},
#   {'itemId': 'B004HA6DQE'},
#   {'itemId': 'B00EDXZ12M'},
#   {'itemId': '1467946516'},
#   {'itemId': 'B00HJFMQUG'},
#   {'itemId': 'B000ME3M5O'},
#   {'itemId': 'B000CSUL2M'},
#   {'itemId': 'B00DLU5QSM'},
#   {'itemId': 'B00EWNFFII'},
#   {'itemId': 'B00IVV2MGU'},
#   {'itemId': 'B00K5NPARA'},
#   {'itemId': 'B005EHAKOK'},
#   {'itemId': 'B00GZL0W7Y'},
#   {'itemId': 'B00JYIH97G'},
#   {'itemId': 'B00QVPW1T6'},
#   {'itemId': 'B00B5O55VY'},
#   {'itemId': 'B00SFOI0WI'},
#   {'itemId': 'B00AYJ0UEI'},
#   {'itemId': 'B00O0BV3RY'},
#   {'itemId': 'B00GNM6AQW'},
#   {'itemId': 'B00793EL74'},
#   {'itemId': 'B005EV3CRS'},
#   {'itemId': 'B000CSUL36'},
#   {'itemId': 'B014C5K1Q6'},
#   {'itemId': 'B00OZY9WR4'},
#   {'itemId': 'B000F8O2MO'},
#   {'itemId': 'B00O3V6T8Y'},
#   {'itemId': 'B000BCGFDS'},
#   {'itemId': 'B006XND3NO'},
#   {'itemId': 'B001OO4EB2'}],
#  'recommendationId': 'RID-63d339a9-64d7-4fcf-a9ac-e8481e31b812'}

# %% [markdown]
# Now add the reranked items as a second column to the original dataframe, for a side-by-side comparison.

# %%
ranked_list = []
item_list = get_recommendations_response_rerank['personalizedRanking']
for item in item_list:
    movie = get_product_by_id(item['itemId'], items_df)
    ranked_list.append(movie)
ranked_df = pd.DataFrame(ranked_list, columns = ['Original','Re-Ranked'])
compare_df = pd.concat([rerank_df, ranked_df], axis=1)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', None)
compare_df
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:8: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#                                                                                          0  \
# 0   COACH SIGNATURE by Coach
# 1   Coach
# 2   Coach
# 3   Coach
# 4   Coach
# 5   Coach
# 6   Coach
# 7   Coach
# 8   Coach
# 9   Coach
# 10  Coach
# 11  Coach
# 12  Coach COACH 22418M-SVB8F Coach  Hamptons Weekend Hippie Crossbody                Black
# 13  COACH House of Coach Coffret Set
# 14  Kitchen Coach: Weekend Cooking (Kitchen Coach)
# 15  COACH CARTER (WS) COACH CARTER (WS)
# 16  Coach Legacy By Coach For Women
# 17  Coach Love Perfume By Coach For Women
# 18  Coach Handbags, Coach Signature Lunch Tote (Black)
# 19  Coach Coach Legacy Leather Rory Satchel 19892
# 20  Coach Stopwatch
# 21  Coach Carter
# 22  Singing Coach
# 23  College Coach
# 24  Coach Nick
# 25  Coach & Earring
# 26  Coach Carter
# 27  Coach Carter
# 28  COACH S2005
# 29  Coach Me
# 30  Stage-coach
# 31  Coach Carter
# 32  Comeback Coach
# 33  Failure Coach
# 34  Coach [VHS]
# 35  Wanted:Rowing Coach
# 36  City Coach
# 37  Coach Carter
# 38  COACH S2001
# 39  COACH S2022
# 40  Ear Coach
# 41  Coach Keychain
# 42  Language Coach
# 43  Coach Carter
# 44  COACH CARTER
# 45  Coach Poppy Flower Perfume By Coach For Women
# 46  COACH POPPY by Coach BODY LOTION 5 OZ
# 47  Coach Perfume by Coach for women Personal Fragrances
# 48  Coach Poppy Flower Perfume By Coach For Women
# 49  Coach Poppy Wildflower Perfume By Coach For Women
# 50  COACH CARTER (DVD/WS) COACH CARTER (DVD/WS)
# 51  Coach Perfume by Coach for women Personal Fragrances
# 52  Coach 2 x 0.17 oz Eau de Parfum Dual Rollerball Coach Poppy / Coach Poppy Blossom
# 53  Coach Poppy Perfume by Coach for women Personal Fragrances
# 54  Coach Watches- Coach Lexington All Stainless Steel Women's Watch
# 55  Coach Eau de Parfum Spray, Coach Love, 1.7 Ounce
# 56  Sight Words Coach
# 57  NFL Head Coach
# 58  Coach Peyton Cora
# 59  Coach Vinni Boot
# 60  Coach Peyton Cora
# 61  Life Coach Tarot
# 62  Coach Sis Tote
# 63  Coach Madison Watch
# 64  The Timeshare Coach
# 65  Coach Poppy Perfume by Coach for women Personal Fragrances
# 66  Coach Ashley Black Leather Satchel F15445 Bag - Coach 15445BK
# 67  Coach Bill McCartney
# 68  Coach Park Hobo
# 69  The Coach House
# 70  The Coach House
# 71  Coach Park Hobo
# 72  My Word Coach
# 73  NFL Head Coach
# 74  L4D - Coach Soundboard
# 75  Low Carb Coach
# 76  Coach Lanyard Blue
# 77  COACH Womens Talia
# 78  Coach English Lite
# 79  Coach Peyton Cora
# 80  COACH Womens 0HC8084
# 81  Coach Shoulder Handbag
# 82  Chinese Mandarin Coach
# 83  COACH Womens 0HC7045
# 84  Coach: Season 4
# 85  The Life Coach
# 86  Coach Like Pop
# 87  Coach Peyton Convertible
# 88  Coach Vinni Boot
# 89  Wedding Coach Theme
# 90  My Diet Coach
# 91  NFL Head Coach
# 92  CEO Strength Coach
# 93  COACH Women's Tristee
# 94  Coach: Season 1
# 95  Coach Peyton Cora
# 96  Singing Coach Kidz
# 97  The Cheerleader's Coach
# 98  Coach Poppy Perfume by Coach for women Personal Fragrances
# 99  Coach Watches- Coach Legacy with Signature Strap Women's Watch
#
#                          1  \
# 0   Beauty
# 1   Video_DVD
# 2   Video_DVD
# 3   Digital_Video_Download
# 4   Digital_Video_Download
# 5   Digital_Ebook_Purchase
# 6   Video_DVD
# 7   Video_DVD
# 8   Apparel
# 9   Digital_Video_Download
# 10  Digital_Video_Download
# 11  Books
# 12  Shoes
# 13  Beauty
# 14  Books
# 15  Video_DVD
# 16  Beauty
# 17  Beauty
# 18  Shoes
# 19  Shoes
# 20  Sports
# 21  Video_DVD
# 22  Software
# 23  Video_DVD
# 24  Digital_Music_Purchase
# 25  Sports
# 26  Video_DVD
# 27  Digital_Video_Download
# 28  Health_&_Personal_Care
# 29  Mobile_Apps
# 30  Books
# 31  Digital_Video_Download
# 32  Digital_Ebook_Purchase
# 33  Books
# 34  Video
# 35  Books
# 36  Toys
# 37  Video_DVD
# 38  Health_&_Personal_Care
# 39  Health_&_Personal_Care
# 40  Mobile_Apps
# 41  Apparel
# 42  Mobile_Apps
# 43  Digital_Video_Download
# 44  Digital_Video_Download
# 45  Beauty
# 46  Beauty
# 47  Beauty
# 48  Beauty
# 49  Beauty
# 50  Video_DVD
# 51  Beauty
# 52  Beauty
# 53  Beauty
# 54  Watches
# 55  Beauty
# 56  Mobile_Apps
# 57  Video_Games
# 58  Shoes
# 59  Shoes
# 60  Shoes
# 61  Digital_Ebook_Purchase
# 62  Luggage
# 63  Watches
# 64  Digital_Ebook_Purchase
# 65  Beauty
# 66  Shoes
# 67  Digital_Music_Purchase
# 68  Shoes
# 69  Digital_Ebook_Purchase
# 70  Books
# 71  Shoes
# 72  Video_Games
# 73  Video_Games
# 74  Mobile_Apps
# 75  Digital_Ebook_Purchase
# 76  Office_Products
# 77  Shoes
# 78  Mobile_Apps
# 79  Shoes
# 80  Shoes
# 81  Shoes
# 82  Mobile_Apps
# 83  Shoes
# 84  Video_DVD
# 85  Digital_Ebook_Purchase
# 86  Digital_Ebook_Purchase
# 87  Shoes
# 88  Shoes
# 89  Toys
# 90  Mobile_Apps
# 91  Video_Games
# 92  Digital_Ebook_Purchase
# 93  Shoes
# 94  Video_DVD
# 95  Shoes
# 96  Software
# 97  Digital_Ebook_Purchase
# 98  Beauty
# 99  Watches
#
#                                                                                   Original  \
# 0   Language Coach
# 1   Coach Carter
# 2   Coach Poppy Flower Perfume By Coach For Women
# 3   Coach: Season 4
# 4   Coach Poppy Perfume by Coach for women Personal Fragrances
# 5   Coach Perfume by Coach for women Personal Fragrances
# 6   Coach Poppy Perfume by Coach for women Personal Fragrances
# 7   My Diet Coach
# 8   Coach Legacy By Coach For Women
# 9   The Coach House
# 10  COACH SIGNATURE by Coach
# 11  Coach
# 12  Coach
# 13  Coach
# 14  Coach
# 15  Coach
# 16  Coach
# 17  Coach
# 18  Coach
# 19  Coach
# 20  Coach
# 21  Coach
# 22  Coach COACH 22418M-SVB8F Coach  Hamptons Weekend Hippie Crossbody                Black
# 23  COACH House of Coach Coffret Set
# 24  Kitchen Coach: Weekend Cooking (Kitchen Coach)
# 25  COACH CARTER (WS) COACH CARTER (WS)
# 26  Coach Love Perfume By Coach For Women
# 27  Coach Handbags, Coach Signature Lunch Tote (Black)
# 28  Coach Coach Legacy Leather Rory Satchel 19892
# 29  Coach Stopwatch
# 30  Coach Carter
# 31  Singing Coach
# 32  College Coach
# 33  Coach Nick
# 34  Coach & Earring
# 35  Coach Carter
# 36  COACH S2005
# 37  Coach Me
# 38  Stage-coach
# 39  Coach Carter
# 40  Comeback Coach
# 41  Failure Coach
# 42  Coach [VHS]
# 43  Wanted:Rowing Coach
# 44  City Coach
# 45  Coach Carter
# 46  COACH S2001
# 47  COACH S2022
# 48  Ear Coach
# 49  Coach Keychain
# 50  Coach Carter
# 51  COACH CARTER
# 52  Coach Poppy Flower Perfume By Coach For Women
# 53  COACH POPPY by Coach BODY LOTION 5 OZ
# 54  Coach Perfume by Coach for women Personal Fragrances
# 55  Coach Poppy Wildflower Perfume By Coach For Women
# 56  COACH CARTER (DVD/WS) COACH CARTER (DVD/WS)
# 57  Coach 2 x 0.17 oz Eau de Parfum Dual Rollerball Coach Poppy / Coach Poppy Blossom
# 58  Coach Poppy Perfume by Coach for women Personal Fragrances
# 59  Coach Watches- Coach Lexington All Stainless Steel Women's Watch
# 60  Coach Eau de Parfum Spray, Coach Love, 1.7 Ounce
# 61  Sight Words Coach
# 62  NFL Head Coach
# 63  Coach Peyton Cora
# 64  Coach Vinni Boot
# 65  Coach Peyton Cora
# 66  Life Coach Tarot
# 67  Coach Sis Tote
# 68  Coach Madison Watch
# 69  The Timeshare Coach
# 70  Coach Ashley Black Leather Satchel F15445 Bag - Coach 15445BK
# 71  Coach Bill McCartney
# 72  Coach Park Hobo
# 73  The Coach House
# 74  Coach Park Hobo
# 75  My Word Coach
# 76  NFL Head Coach
# 77  L4D - Coach Soundboard
# 78  Low Carb Coach
# 79  Coach Lanyard Blue
# 80  COACH Womens Talia
# 81  Coach English Lite
# 82  Coach Peyton Cora
# 83  COACH Womens 0HC8084
# 84  Coach Shoulder Handbag
# 85  Chinese Mandarin Coach
# 86  COACH Womens 0HC7045
# 87  The Life Coach
# 88  Coach Like Pop
# 89  Coach Peyton Convertible
# 90  Coach Vinni Boot
# 91  Wedding Coach Theme
# 92  NFL Head Coach
# 93  CEO Strength Coach
# 94  COACH Women's Tristee
# 95  Coach: Season 1
# 96  Coach Peyton Cora
# 97  Singing Coach Kidz
# 98  The Cheerleader's Coach
# 99  Coach Watches- Coach Legacy with Signature Strap Women's Watch
#
#                  Re-Ranked
# 0   Mobile_Apps
# 1   Video_DVD
# 2   Beauty
# 3   Video_DVD
# 4   Beauty
# 5   Beauty
# 6   Beauty
# 7   Mobile_Apps
# 8   Beauty
# 9   Digital_Ebook_Purchase
# 10  Beauty
# 11  Video_DVD
# 12  Video_DVD
# 13  Digital_Video_Download
# 14  Digital_Video_Download
# 15  Digital_Ebook_Purchase
# 16  Video_DVD
# 17  Video_DVD
# 18  Apparel
# 19  Digital_Video_Download
# 20  Digital_Video_Download
# 21  Books
# 22  Shoes
# 23  Beauty
# 24  Books
# 25  Video_DVD
# 26  Beauty
# 27  Shoes
# 28  Shoes
# 29  Sports
# 30  Video_DVD
# 31  Software
# 32  Video_DVD
# 33  Digital_Music_Purchase
# 34  Sports
# 35  Digital_Video_Download
# 36  Health_&_Personal_Care
# 37  Mobile_Apps
# 38  Books
# 39  Digital_Video_Download
# 40  Digital_Ebook_Purchase
# 41  Books
# 42  Video
# 43  Books
# 44  Toys
# 45  Video_DVD
# 46  Health_&_Personal_Care
# 47  Health_&_Personal_Care
# 48  Mobile_Apps
# 49  Apparel
# 50  Digital_Video_Download
# 51  Digital_Video_Download
# 52  Beauty
# 53  Beauty
# 54  Beauty
# 55  Beauty
# 56  Video_DVD
# 57  Beauty
# 58  Beauty
# 59  Watches
# 60  Beauty
# 61  Mobile_Apps
# 62  Video_Games
# 63  Shoes
# 64  Shoes
# 65  Shoes
# 66  Digital_Ebook_Purchase
# 67  Luggage
# 68  Watches
# 69  Digital_Ebook_Purchase
# 70  Shoes
# 71  Digital_Music_Purchase
# 72  Shoes
# 73  Books
# 74  Shoes
# 75  Video_Games
# 76  Video_Games
# 77  Mobile_Apps
# 78  Digital_Ebook_Purchase
# 79  Office_Products
# 80  Shoes
# 81  Mobile_Apps
# 82  Shoes
# 83  Shoes
# 84  Shoes
# 85  Mobile_Apps
# 86  Shoes
# 87  Digital_Ebook_Purchase
# 88  Digital_Ebook_Purchase
# 89  Shoes
# 90  Shoes
# 91  Toys
# 92  Video_Games
# 93  Digital_Ebook_Purchase
# 94  Shoes
# 95  Video_DVD
# 96  Shoes
# 97  Software
# 98  Digital_Ebook_Purchase
# 99  Watches

# %% [markdown]
# You can see above how each entry was re-ordered based on the model's understanding of the user. This is a popular task when you have a collection of items to surface a user, a list of promotions for example, or if you are filtering on a category and want to show the most likely good items.
