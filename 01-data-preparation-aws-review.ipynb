# %% [markdown]
# ### Amazon Review Dataset

# %%
# !pip install awswrangler
# Out:
# Requirement already satisfied: awswrangler in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.2.0)
# Requirement already satisfied: numpy<1.20.0,>=1.18.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.18.1)
# Requirement already satisfied: redshift-connector~=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (2.0.872)
# Requirement already satisfied: pyarrow~=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (2.0.0)
# Requirement already satisfied: pandas<1.2.0,>=1.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.1.5)
# Requirement already satisfied: boto3<2.0.0,>=1.12.49 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.16.37)
# Requirement already satisfied: pg8000~=1.16.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.16.6)
# Requirement already satisfied: pymysql<0.11.0,>=0.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (0.10.1)
# Requirement already satisfied: botocore<2.0.0,>=1.15.49 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.19.37)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0.0,>=1.12.49->awswrangler) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0.0,>=1.12.49->awswrangler) (0.10.0)
# Requirement already satisfied: botocore<2.0.0,>=1.15.49 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.19.37)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<2.0.0,>=1.15.49->awswrangler) (2.8.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0.0,>=1.12.49->awswrangler) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<2.0.0,>=1.15.49->awswrangler) (1.25.11)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<2.0.0,>=1.15.49->awswrangler) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas<1.2.0,>=1.1.0->awswrangler) (2020.5)
# Requirement already satisfied: numpy<1.20.0,>=1.18.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.18.1)
# Requirement already satisfied: scramp==1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pg8000~=1.16.0->awswrangler) (1.2.0)
# Requirement already satisfied: numpy<1.20.0,>=1.18.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.18.1)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.15.49->awswrangler) (1.15.0)
# Requirement already satisfied: scramp==1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pg8000~=1.16.0->awswrangler) (1.2.0)
# Requirement already satisfied: botocore<2.0.0,>=1.15.49 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.19.37)
# Requirement already satisfied: boto3<2.0.0,>=1.12.49 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.16.37)
# Requirement already satisfied: beautifulsoup4>=4.7.0<4.8.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from redshift-connector~=2.0.0->awswrangler) (4.8.2)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas<1.2.0,>=1.1.0->awswrangler) (2020.5)
# Requirement already satisfied: lxml>=4.2.5<4.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from redshift-connector~=2.0.0->awswrangler) (4.6.2)
# Requirement already satisfied: requests>=2.23.0<2.24.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from redshift-connector~=2.0.0->awswrangler) (2.25.0)
# Requirement already satisfied: soupsieve>=1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from beautifulsoup4>=4.7.0<4.8.0->redshift-connector~=2.0.0->awswrangler) (1.9.5)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<2.0.0,>=1.15.49->awswrangler) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.23.0<2.24.0->redshift-connector~=2.0.0->awswrangler) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.23.0<2.24.0->redshift-connector~=2.0.0->awswrangler) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.23.0<2.24.0->redshift-connector~=2.0.0->awswrangler) (2020.11.8)
# Requirement already satisfied: botocore<2.0.0,>=1.15.49 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.19.37)
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
import awswrangler as wr 
import pandas as pd

# %%
product_query = '''SELECT distinct product_id, product_category, product_title
    FROM 
    (SELECT *
    FROM 
        (SELECT customer_id,
         count(*) AS cnt
        FROM (select * from amazon_reviews_parquet where year>=2015)
        GROUP BY  customer_id)
        WHERE cnt >= 5 ) AS a
    JOIN amazon_reviews_parquet AS pca
    ON pca.customer_id = a.customer_id'''



item_df = wr.athena.read_sql_query(product_query, database="default", ctas_approach=False)

# %%
item_df.head()
# Out:
#    product_id        product_category  \
# 0  B001T4GX5C                Outdoors
# 1  B003VWXXXK                 Kitchen
# 2  B002SMJQT4  Health_&_Personal_Care
# 3  B001EQ56DA                 Grocery
# 4  B005SPZG5Q                    Baby
#
#                                        product_title
# 0                         Lucky Hardware Lucky Green
# 1  Ninja Professional Blender (NJ600) (Discontinued)
# 2          Adaptive Sound Technologies - Sound+Sleep
# 3   EnviroKidz Organic Chocolate  Koala Crisp Cereal
# 4                                    Brica Drink Pod

# %%
item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11570547 entries, 0 to 11570546
# Data columns (total 3 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   product_id        string
#  1   product_category  string
#  2   product_title     string
# dtypes: string(3)
# memory usage: 264.8 MB

# %%
user_item_query = '''SELECT product_id, product_category,a.customer_id, star_rating, review_date*86400 as timestamp 
    FROM 
    (SELECT *
    FROM 
        (SELECT customer_id,
         count(*) AS cnt
        FROM (select * from amazon_reviews_parquet where year>=2015)
        GROUP BY  customer_id)
        WHERE cnt >= 5 ) AS a
    JOIN amazon_reviews_parquet AS pca
    ON pca.customer_id = a.customer_id'''

ui_df = wr.athena.read_sql_query(user_item_query, database="default", ctas_approach=False)

# %%
ui_df.head()
# Out:
#    product_id  product_category customer_id  star_rating   timestamp
# 0  B009SA8XSY             Music     6673125            2  1425168000
# 1  B0012C7JO0          Outdoors     6673125            5  1425168000
# 2  B00DBJKYQC            Sports     6673125            4  1431734400
# 3  B0073MG11A        Automotive     6673125            4  1382918400
# 4  B004DNWVOI  Home_Improvement     6673125            5  1431734400

# %%
ui_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55921681 entries, 0 to 55921680
# Data columns (total 5 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   product_id        string
#  1   product_category  string
#  2   customer_id       string
#  3   star_rating       Int32
#  4   timestamp         Int64
# dtypes: Int32(1), Int64(1), string(3)
# memory usage: 2.0 GB

# %% [markdown]
# ### Prepare to insert into Elastic Search

# %%
# !pip install requests 
# !pip install requests-aws4auth
# !pip install Elasticsearch==7.7.0 
# !pip install urllib3
# Out:
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.25.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests) (2020.11.8)
# Requirement already satisfied: idna<3,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests) (2.10)
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Collecting requests-aws4auth
#   Downloading requests_aws4auth-1.0.1-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests-aws4auth) (2.25.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->requests-aws4auth) (2020.11.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->requests-aws4auth) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->requests-aws4auth) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->requests-aws4auth) (2.10)
# Installing collected packages: requests-aws4auth
# Successfully installed requests-aws4auth-1.0.1
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Collecting Elasticsearch==7.7.0
#   Downloading elasticsearch-7.7.0-py2.py3-none-any.whl (99 kB)
#      |████████████████████████████████| 99 kB 2.1 MB/s  eta 0:00:01
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from Elasticsearch==7.7.0) (2020.11.8)
# Requirement already satisfied: urllib3>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from Elasticsearch==7.7.0) (1.25.11)
# Installing collected packages: Elasticsearch
# Successfully installed Elasticsearch-7.7.0
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: urllib3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.25.11)
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
elastic_search_endpoint=input()
# Out:
# search-amazon-review-demo-6z6ub2pwv5lfhpgvqnyxjb2g6q.us-east-1.es.amazonaws.com

# %%
from requests_aws4auth import AWS4Auth
import boto3

host = elastic_search_endpoint
session = boto3.session.Session()
region = session.region_name

service = 'es'
credentials = boto3.Session().get_credentials()
awsauth = AWS4Auth(credentials.access_key, credentials.secret_key, region, service, session_token=credentials.token)

# %%
master_user=input()

# %%
master_user_password=input()

# %%
import boto3
import json
from elasticsearch import Elasticsearch, RequestsHttpConnection
def connectES(esEndPoint):
    print ('Connecting to the ES Endpoint {0}'.format(esEndPoint))
    try:
        esClient = Elasticsearch(
        hosts=[{'host': esEndPoint, 'port': 443}],
        http_auth=awsauth,
        use_ssl=True,
        verify_certs=True,
        connection_class=RequestsHttpConnection)
        return esClient
    except Exception as E:
        print("Unable to connect to {0}".format(esEndPoint))
        print(E)
        exit(3)

# %%
esClient = connectES(elastic_search_endpoint)
# Out:
# Connecting to the ES Endpoint search-amazon-review-demo-6z6ub2pwv5lfhpgvqnyxjb2g6q.us-east-1.es.amazonaws.com

# %%
def indexDocElement(esClient, response):
    try:
        retval = esClient.index(index='product', doc_type='product', body=response)
    except Exception as E:
        print("Doc not indexed")
        print("Error: ",E)
        exit(5)

# %%
item_df = item_df.fillna("")
item_arr = item_df.to_dict(orient="records")
import json

for i, j in enumerate(item_arr):
    indexDocElement(esClient,response=j)

# %%
import requests
r = requests.get('https://{}/product/product/_search?q=product_title:black&size=100'.format(elastic_search_endpoint), auth=awsauth)
rjson = r.json()
rjson
# Out:
# {'took': 58,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 5.191208,
#   'hits': [{'_index': 'product',
#     '_type': 'product',
#     '_id': 'nOS7V3YBWQlvJU18Ij_u',
#     '_score': 5.191208,
#     '_source': {'product_id': 'B004WED3YK',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Black Is Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'lfjtU3YB1EYWinhnpehP',
#     '_score': 5.191208,
#     '_source': {'product_id': 'B0044I7GP6',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Black Is Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '1A0AXHYB1EYWinhnm9_A',
#     '_score': 5.191208,
#     '_source': {'product_id': 'B0013GO22M',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Black Is Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'I0t4VnYB7ZcjQTga_Xqv',
#     '_score': 5.189479,
#     '_source': {'product_id': 'B0050OJWZU',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Black Is Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'Fu1TW3YBWQlvJU18pJVg',
#     '_score': 5.189479,
#     '_source': {'product_id': 'B00ARY40J6',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Yellow & Black & Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '6xFnXXYB1EYWinhnuYIL',
#     '_score': 5.189479,
#     '_source': {'product_id': 'B002QSDKW4',
#      'product_category': 'Apparel',
#      'product_title': 'Black Petticoat - Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'XmWfYHYB7ZcjQTgaxtTn',
#     '_score': 5.1887054,
#     '_source': {'product_id': '0692375791',
#      'product_category': 'Books',
#      'product_title': 'Black Man, Black Woman, Black Child'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'n3DfZHYB7ZcjQTga7N13',
#     '_score': 5.186026,
#     '_source': {'product_id': 'B000050KA0',
#      'product_category': 'Music',
#      'product_title': 'Black Is Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '3T1gUnYB7ZcjQTga_iAD',
#     '_score': 5.181527,
#     '_source': {'product_id': 'B006JO4GPQ',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Black Is Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '7PYeU3YB1EYWinhnOs12',
#     '_score': 5.181527,
#     '_source': {'product_id': 'B008B0BQ7W',
#      'product_category': 'Music',
#      'product_title': 'Black Is Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'TlCXWHYB7ZcjQTgaovry',
#     '_score': 5.181527,
#     '_source': {'product_id': 'B000XZBXH6',
#      'product_category': 'Music',
#      'product_title': 'Black On Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'JWwdY3YB7ZcjQTgaAEuP',
#     '_score': 5.181527,
#     '_source': {'product_id': 'B001QLEXB4',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Black Is Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'z_d3U3YB1EYWinhn5LZQ',
#     '_score': 5.180455,
#     '_source': {'product_id': 'B002CZJUIY',
#      'product_category': 'Electronics',
#      'product_title': 'RIOT Black/Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'z0oOVnYB7ZcjQTgakmWq',
#     '_score': 5.180455,
#     '_source': {'product_id': '0671577883',
#      'product_category': 'Books',
#      'product_title': 'Black on Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'eRtoYXYB1EYWinhngedS',
#     '_score': 5.180455,
#     '_source': {'product_id': 'B00CM1O0H4',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Black Is Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'RtOAUnYBWQlvJU18fOmT',
#     '_score': 5.139876,
#     '_source': {'product_id': 'B00P6MX51I',
#      'product_category': 'Wireless',
#      'product_title': 'OtterBox SONY Xperia Z3v Case - OtterBox DEFENDER SERIES, BLACK (BLACK/BLACK) - Carrying Case  - BLACK (BLACK/BLACK)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'Q_kSVHYB1EYWinhn9kkf',
#     '_score': 5.1361775,
#     '_source': {'product_id': 'B00P6MX4XM',
#      'product_category': 'Wireless',
#      'product_title': 'OtterBox SONY Xperia Z3v Case - OtterBox DEFENDER SERIES, BLACK (BLACK/BLACK) - Carrying Case  - BLACK (BLACK/BLACK)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '9vkaYHYBWQlvJU18Q_lQ',
#     '_score': 5.105002,
#     '_source': {'product_id': 'B00O4BD2ME',
#      'product_category': 'Apparel',
#      'product_title': "Zenana Women's Lounge Pants, 4 Pk Black, Black, Black, Black"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'e2YOYXYB7ZcjQTgaSvMO',
#     '_score': 5.0972004,
#     '_source': {'product_id': 'B00O4BD1UW',
#      'product_category': 'Apparel',
#      'product_title': "Zenana Women's Lounge Pants, 4 Pk Black, Black, Black, Black"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'cQioUXYBXrWQULofn5a8',
#     '_score': 5.0774508,
#     '_source': {'product_id': 'B00L3M0R7A',
#      'product_category': 'Wireless',
#      'product_title': 'OtterBox Otterbox DEFENDER SERIES for Samsung GALAXY S5 Active, BLACK (BLACK/BLACK) - Carrying Case  - BLACK (BLACK/BLACK)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'Ye4ZUnYB1EYWinhn4F0Y',
#     '_score': 5.0774508,
#     '_source': {'product_id': 'B00L3M1KA8',
#      'product_category': 'Wireless',
#      'product_title': 'OtterBox Otterbox DEFENDER SERIES for Samsung GALAXY S5 Active, BLACK (BLACK/BLACK) - Carrying Case  - BLACK (BLACK/BLACK)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'FhNbXnYB1EYWinhnu_xJ',
#     '_score': 5.070598,
#     '_source': {'product_id': 'B002WUEVEW',
#      'product_category': 'Watches',
#      'product_title': 'Obaku Black Silicone Black Strap Black Dial'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'zmH0XnYB7ZcjQTgabn4o',
#     '_score': 5.070598,
#     '_source': {'product_id': 'B00J43US42',
#      'product_category': 'Health_&_Personal_Care',
#      'product_title': 'BLACK GLOVEABLES, BLACK CHERRY TRIM, BLACK BOW'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'Vgm5UXYBXrWQULofBC8h',
#     '_score': 5.069698,
#     '_source': {'product_id': 'B00L3M0R7A',
#      'product_category': 'Wireless',
#      'product_title': 'OtterBox Otterbox DEFENDER SERIES for Samsung GALAXY S5 Active, BLACK (BLACK/BLACK) - Carrying Case  - BLACK (BLACK/BLACK)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'HMzBUXYBWQlvJU189lnN',
#     '_score': 5.069698,
#     '_source': {'product_id': 'B00L3M0R7A',
#      'product_category': 'Wireless',
#      'product_title': 'OtterBox Otterbox DEFENDER SERIES for Samsung GALAXY S5 Active, BLACK (BLACK/BLACK) - Carrying Case  - BLACK (BLACK/BLACK)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'Yv8pYnYBWQlvJU18i1P-',
#     '_score': 5.0670366,
#     '_source': {'product_id': 'B004IEIL0A',
#      'product_category': 'Outdoors',
#      'product_title': 'Timbuk2 Q Backpack, Black/Black/Black, Medium'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'JhE5XXYB1EYWinhn9Ayz',
#     '_score': 5.062845,
#     '_source': {'product_id': 'B008MQQGXO',
#      'product_category': 'Shoes',
#      'product_title': 'Nike Tailwind Sunglasses Black Polarized (Black, Black)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '5fQlXnYBWQlvJU18ceUj',
#     '_score': 5.062845,
#     '_source': {'product_id': 'B004IK035K',
#      'product_category': 'Outdoors',
#      'product_title': 'Timbuk2 Bifold Wallet, Black/Black/Black, Medium'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'IB0pYnYB1EYWinhn-t46',
#     '_score': 5.062845,
#     '_source': {'product_id': 'B001DVVWA2',
#      'product_category': 'Luggage',
#      'product_title': "Timbuk2 Women's Metro Bag (Black/ Black/ Black)"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '_Q0AXHYB1EYWinhnR97R',
#     '_score': 5.061675,
#     '_source': {'product_id': 'B00HEVK09E',
#      'product_category': 'Digital_Ebook_Purchase',
#      'product_title': 'BLACK Is The New Black (BLACK #3)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'UB47YnYB1EYWinhnYAth',
#     '_score': 5.061675,
#     '_source': {'product_id': 'B00J43UOBO',
#      'product_category': 'Health_&_Personal_Care',
#      'product_title': 'BLACK GLOVEABLES, BLACK GINGHAM TRIM, BLACK BOW'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'RyF6Y3YB1EYWinhn3UlQ',
#     '_score': 5.061675,
#     '_source': {'product_id': 'B004IK3YLA',
#      'product_category': 'Outdoors',
#      'product_title': 'Timbuk2 Click Bag, Black/Black/Black, Medium'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '4mPEX3YB7ZcjQTgadJpO',
#     '_score': 5.004698,
#     '_source': {'product_id': 'B00TTFYW0G',
#      'product_category': 'Digital_Ebook_Purchase',
#      'product_title': 'Black Star, Black Sun'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'n2TsX3YB7ZcjQTga0gOk',
#     '_score': 5.004698,
#     '_source': {'product_id': 'B003MEDEF4',
#      'product_category': 'Digital_Video_Download',
#      'product_title': "Black Is... Black Ain't"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '2f2UYXYBWQlvJU18vNDj',
#     '_score': 5.004698,
#     '_source': {'product_id': 'B000J2V6A2',
#      'product_category': 'Apparel',
#      'product_title': 'Adult Black Crinoline - Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '6AblZHYBWQlvJU18wWya',
#     '_score': 5.004698,
#     '_source': {'product_id': 'B008EASYC4',
#      'product_category': 'Beauty',
#      'product_title': 'MAC Chromaline BLACK BLACK'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'iMzHUXYBWQlvJU18pJBp',
#     '_score': 5.0031633,
#     '_source': {'product_id': 'B001HBVE88',
#      'product_category': 'Video_DVD',
#      'product_title': "Black Is...Black Ain't"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'QdN5UnYBWQlvJU18iqCw',
#     '_score': 5.0031633,
#     '_source': {'product_id': 'B000H8KERE',
#      'product_category': 'Toys',
#      'product_title': 'Girls Black Crinoline - Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'EdWzUnYBWQlvJU18uORP',
#     '_score': 5.0031633,
#     '_source': {'product_id': '1601605412',
#      'product_category': 'Books',
#      'product_title': 'CoolNotes (Small): Black/Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '_AgOWnYB1EYWinhn_tIq',
#     '_score': 5.0031633,
#     '_source': {'product_id': 'B001K2CX70',
#      'product_category': 'Sports',
#      'product_title': 'Black Sports Headband, Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'dlf8WnYB7ZcjQTgasTK5',
#     '_score': 5.0031633,
#     '_source': {'product_id': 'B001QLEXAK',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Black Is Black [Explicit]'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'EW8qZHYB7ZcjQTgaMAYh',
#     '_score': 5.0031633,
#     '_source': {'product_id': 'B00V9457R2',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Black Cross, Black Shield'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'JQW3ZHYBWQlvJU18KfSL',
#     '_score': 5.0031633,
#     '_source': {'product_id': 'B0037AGZJK',
#      'product_category': 'Health_&_Personal_Care',
#      'product_title': 'Smooth Black Dildo - Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '_czJUXYBWQlvJU189KXW',
#     '_score': 4.9997325,
#     '_source': {'product_id': 'B002FAM62S',
#      'product_category': 'Shoes',
#      'product_title': 'SOFFT BLACK/BLACK PATENT'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '4giuUXYBXrWQULofDM0W',
#     '_score': 4.9997325,
#     '_source': {'product_id': 'B001HBVE88',
#      'product_category': 'Video_DVD',
#      'product_title': "Black Is...Black Ain't"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'gwiwUXYBXrWQULofOuOC',
#     '_score': 4.9997325,
#     '_source': {'product_id': 'B002FAM62S',
#      'product_category': 'Shoes',
#      'product_title': 'SOFFT BLACK/BLACK PATENT'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'TPSvUnYB1EYWinhntkZc',
#     '_score': 4.9997325,
#     '_source': {'product_id': 'B003IFGVES',
#      'product_category': 'Apparel',
#      'product_title': 'Black Afro Wig Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'lUZ7VHYB7ZcjQTga8U-0',
#     '_score': 4.9997325,
#     '_source': {'product_id': 'B00C6FGRAE',
#      'product_category': 'Apparel',
#      'product_title': 'ChachiMomma Pants Black Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'NUcXVXYB7ZcjQTgaQeMH',
#     '_score': 4.9997325,
#     '_source': {'product_id': 'B00A4OF1Q0',
#      'product_category': 'Health_&_Personal_Care',
#      'product_title': 'VaporBLUNT Vaporizer - Black/Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '4PxFVXYB1EYWinhnmWXE',
#     '_score': 4.9997325,
#     '_source': {'product_id': 'B006MPM1JK',
#      'product_category': 'Outdoors',
#      'product_title': 'Cressi Superocchio, black/black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'iefNWHYBWQlvJU18lge2',
#     '_score': 4.9997325,
#     '_source': {'product_id': 'B00137KHJI',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Black On Black II'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '8STOZHYB1EYWinhnn7oo',
#     '_score': 4.9997325,
#     '_source': {'product_id': 'B004W479JK',
#      'product_category': 'Home_Improvement',
#      'product_title': 'Montana Black 400Ml Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'JtgPU3YBWQlvJU18GB27',
#     '_score': 4.9955063,
#     '_source': {'product_id': 'B00MSE6924',
#      'product_category': 'Digital_Ebook_Purchase',
#      'product_title': 'Black Rider / Black Train'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '7_d-U3YB1EYWinhnGsYF',
#     '_score': 4.9955063,
#     '_source': {'product_id': 'B00MK0VWUU',
#      'product_category': 'Home',
#      'product_title': 'Montana Black 50Ml Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '8_kWVHYB1EYWinhnTlEP',
#     '_score': 4.9955063,
#     '_source': {'product_id': 'B007WP5ER0',
#      'product_category': 'Jewelry',
#      'product_title': 'Black on Black Cufflinks'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '7gq6WnYB1EYWinhn75E1',
#     '_score': 4.9955063,
#     '_source': {'product_id': '0993718035',
#      'product_category': 'Books',
#      'product_title': 'Black Star, Black Sun'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'pV7YXXYB7ZcjQTga6Z4b',
#     '_score': 4.9955063,
#     '_source': {'product_id': '1906694834',
#      'product_category': 'Books',
#      'product_title': 'Black Sky, Black Sea'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'lRLnXXYB1EYWinhnbM5f',
#     '_score': 4.9955063,
#     '_source': {'product_id': '0813532159',
#      'product_category': 'Books',
#      'product_title': 'Black Victorians, Black Victoriana'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'g2PMX3YB7ZcjQTgaxrAO',
#     '_score': 4.9955063,
#     '_source': {'product_id': 'B001YWHZ5Q',
#      'product_category': 'Shoes',
#      'product_title': 'SOFFT HALTON BLACK/BLACK'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '4GQVYHYB7ZcjQTgazm0X',
#     '_score': 4.9955063,
#     '_source': {'product_id': 'B00EGI840K',
#      'product_category': 'Video_DVD',
#      'product_title': 'BLACK BEAUTY BLACK BEAUTY'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'UR-cYnYB1EYWinhnUQfR',
#     '_score': 4.9955063,
#     '_source': {'product_id': 'B001GH2OBE',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Black On Black [Explicit]'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '1GwNY3YB7ZcjQTgaDiHF',
#     '_score': 4.9955063,
#     '_source': {'product_id': '068825294X',
#      'product_category': 'Books',
#      'product_title': 'Black Feeling Black Talk'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'LAQgZHYBWQlvJU18YW1B',
#     '_score': 4.9955063,
#     '_source': {'product_id': 'B000VOCM6U',
#      'product_category': 'Toys',
#      'product_title': 'Black Makeup Stick - Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'TO0FUnYB1EYWinhn65Op',
#     '_score': 4.9944057,
#     '_source': {'product_id': '1452653526',
#      'product_category': 'Books',
#      'product_title': 'Black Night (Black Wings)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'FNbGUnYBWQlvJU18ZJ4v',
#     '_score': 4.9944057,
#     '_source': {'product_id': 'B003YRIJYU',
#      'product_category': 'Digital_Ebook_Purchase',
#      'product_title': 'Black Dragon, Black Cat'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'x_sRVXYB1EYWinhnoN5T',
#     '_score': 4.9944057,
#     '_source': {'product_id': 'B007136DU0',
#      'product_category': 'Electronics',
#      'product_title': 'Skullcandy Titan - Black/Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'PQYsWXYB1EYWinhn8oge',
#     '_score': 4.9944057,
#     '_source': {'product_id': 'B001UN7MZW',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Black Is Black [Explicit]'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'iR5kYnYB1EYWinhnNnU8',
#     '_score': 4.9944057,
#     '_source': {'product_id': 'B008VGK64K',
#      'product_category': 'Apparel',
#      'product_title': 'Mushroomhead Black Bandana Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'pmu_YnYB7ZcjQTgakljY',
#     '_score': 4.9944057,
#     '_source': {'product_id': 'B001A2T2IS',
#      'product_category': 'Digital_Music_Purchase',
#      'product_title': 'Black On Black Crime'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 't-tiWnYBWQlvJU18DyFV',
#     '_score': 4.9518404,
#     '_source': {'product_id': 'B004S3A7HQ',
#      'product_category': 'Shoes',
#      'product_title': 'adidas adiPURE Z Golf Shoe (Black/Black/Black)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'E0mjVXYB7ZcjQTgaT0_7',
#     '_score': 4.9518404,
#     '_source': {'product_id': 'B004432BTW',
#      'product_category': 'Shoes',
#      'product_title': 'adidas adiPURE Z Golf Shoe (Black/Black/Black)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'i2QbYHYB7ZcjQTga331s',
#     '_score': 4.9518404,
#     '_source': {'product_id': 'B002WC8YMU',
#      'product_category': 'Outdoors',
#      'product_title': 'Timbuk2 Q Laptop Backpack,Black/Black/Black,M'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'N0fnVHYB7ZcjQTgaLGaJ',
#     '_score': 4.9505105,
#     '_source': {'product_id': 'B005VA8P56',
#      'product_category': 'Shoes',
#      'product_title': 'adidas adiPURE Z Golf Shoe (Black/Black/Black)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'FO8pXHYBWQlvJU18vsFu',
#     '_score': 4.9505105,
#     '_source': {'product_id': 'B004434DFM',
#      'product_category': 'Shoes',
#      'product_title': 'adidas adiPURE Z Golf Shoe (Black/Black/Black)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'PO4gUnYB1EYWinhni5wT',
#     '_score': 4.946971,
#     '_source': {'product_id': 'B005K2X8L6',
#      'product_category': 'PC',
#      'product_title': 'Timbuk2 Kindle Fire Element Jacket (Black/Black/Black)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '-_XZUnYB1EYWinhnj-m1',
#     '_score': 4.946971,
#     '_source': {'product_id': 'B002WC902S',
#      'product_category': 'Outdoors',
#      'product_title': 'Timbuk2 ID Money Clip,Black/Black/Black,M'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'EPECXXYBWQlvJU18m_P-',
#     '_score': 4.9429464,
#     '_source': {'product_id': 'B004IJYGLS',
#      'product_category': 'Outdoors',
#      'product_title': 'Timbuk2 2Way Accessory Case, Black/Black/Black, Small'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '8uAtVnYBWQlvJU18SzX_',
#     '_score': 4.941763,
#     '_source': {'product_id': 'B002WC8YO8',
#      'product_category': 'Outdoors',
#      'product_title': 'Timbuk2 H.A.L. Laptop Backpack,Black/Black/Black,M'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'aU0PV3YB7ZcjQTgaLQAy',
#     '_score': 4.929885,
#     '_source': {'product_id': 'B007TSFCT0',
#      'product_category': 'Wireless',
#      'product_title': '10 pcs Bumper Frame Skin Case for all iPhone 4S TPU Silicone Cover (Color available: Black-Red, Black-Orange, Black-Yellow, Black-Green, Black- Purple, Black-Blue, Black-Light Green, Black-Light Purple, Black-White, and Black-Black)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'dkTEU3YB7ZcjQTgaEXK9',
#     '_score': 4.9258285,
#     '_source': {'product_id': 'B00K31E0ZC',
#      'product_category': 'Apparel',
#      'product_title': "4 Pack Zenana Women's Plus Basic Leggings 2X Black, Black, Black, Black"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'dfk_VHYB1EYWinhnbbx5',
#     '_score': 4.9258285,
#     '_source': {'product_id': 'B00JZZ91OM',
#      'product_category': 'Apparel',
#      'product_title': "4 Pack Zenana Women's Basic Tank Tops Large Black, Black, Black, Black"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'mhmmYHYB1EYWinhnAu4E',
#     '_score': 4.9258285,
#     '_source': {'product_id': 'B00K5BLMJC',
#      'product_category': 'Apparel',
#      'product_title': "4 Pack Active Basic Women's Long Cami Small Black, Black, Black, Black"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '1P3EVXYB1EYWinhnS64_',
#     '_score': 4.9245973,
#     '_source': {'product_id': 'B00LTYVSMU',
#      'product_category': 'Apparel',
#      'product_title': "4 Pack Active Basic Women's Yoga Shorts Large Black, Black, Black, Black"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '4Ts6UnYB7ZcjQTgaUpRg',
#     '_score': 4.9210057,
#     '_source': {'product_id': 'B00LTYVUIC',
#      'product_category': 'Apparel',
#      'product_title': "4 Pack Active Basic Women's Yoga Shorts Med Black, Black, Black, Black"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'iOwZW3YBWQlvJU18bP1G',
#     '_score': 4.915856,
#     '_source': {'product_id': 'B00LTYVWDA',
#      'product_category': 'Apparel',
#      'product_title': "4 Pack Active Basic Women's Yoga Shorts Small Black, Black, Black, Black"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '7GWYYHYB7ZcjQTgaTcBf',
#     '_score': 4.915856,
#     '_source': {'product_id': 'B00K31DYZ4',
#      'product_category': 'Apparel',
#      'product_title': "4 Pack Zenana Women's Plus Basic Leggings 1X Black, Black, Black, Black"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '9gV2ZHYBWQlvJU18uEzr',
#     '_score': 4.915856,
#     '_source': {'product_id': 'B00K5BLJ90',
#      'product_category': 'Apparel',
#      'product_title': "4 Pack Active Basic Women's Long Cami Large Black, Black, Black, Black"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '3ONHV3YBWQlvJU18XxI-',
#     '_score': 4.8902187,
#     '_source': {'product_id': 'B00MTWF5RA',
#      'product_category': 'Wireless',
#      'product_title': 'OtterBox OtterBox SYMMETRY SERIES for Samsung GALAXY S5 Mini, BLACK (BLACK/BLACK) - Carrying Case - Frustration-Free Packaging - BLACK (BLACK/BLACK)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'hPdMX3YBWQlvJU185eUK',
#     '_score': 4.839093,
#     '_source': {'product_id': 'B00K596H1C',
#      'product_category': 'Apparel',
#      'product_title': "4 Pack Zenana Women's Lace Trim Tank Tops Large Black, Black, Black, Black"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'EB3cYXYB1EYWinhn6RaF',
#     '_score': 4.839093,
#     '_source': {'product_id': 'B00K596HRG',
#      'product_category': 'Apparel',
#      'product_title': "4 Pack Zenana Women's Lace Trim Tank Tops Med Black, Black, Black, Black"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'SBs8YXYB1EYWinhnkHV7',
#     '_score': 4.8372035,
#     '_source': {'product_id': 'B0061RA0VU',
#      'product_category': 'Outdoors',
#      'product_title': 'Mavic Cyclone Full finger gloves Gentlemen black/black black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'QW1zY3YB7ZcjQTgaNyuN',
#     '_score': 4.8372035,
#     '_source': {'product_id': 'B0030EG3C2',
#      'product_category': 'Digital_Ebook_Purchase',
#      'product_title': 'Mrs. Black? Malcolm Black Book 3 (Malcolm Black Books)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'kOhgWXYBWQlvJU18jYS0',
#     '_score': 4.8359785,
#     '_source': {'product_id': 'B00Q1K1DAO',
#      'product_category': 'Shoes',
#      'product_title': "Sedagatti Men's Black/Black/Black Moc Toe Boat Shoes"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'TPTVXXYBWQlvJU18ahaY',
#     '_score': 4.8359785,
#     '_source': {'product_id': 'B002V92YV6',
#      'product_category': 'Outdoors',
#      'product_title': 'Timbuk2 Freestyle Laptop Messenger Bag,Black/Black/Black,XS'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'BD6BUnYB7ZcjQTga43h2',
#     '_score': 4.8324633,
#     '_source': {'product_id': 'B009F8W3C6',
#      'product_category': 'Wireless',
#      'product_title': 'Griffin iPod Touch 5g Survivor Case (Black/Black/Black)'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'kmvOYnYB7ZcjQTgajn85',
#     '_score': 4.8324633,
#     '_source': {'product_id': 'B00Q1K3N8O',
#      'product_category': 'Shoes',
#      'product_title': "Sedagatti Men's Black/Black/Black Moc Toe Boat Shoes"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '30nRVXYB7ZcjQTgaC8X-',
#     '_score': 4.83171,
#     '_source': {'product_id': 'B00K596IRU',
#      'product_category': 'Apparel',
#      'product_title': "4 Pack Zenana Women's Lace Trim Tank Tops Small Black, Black, Black, Black"}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'a-NlV3YBWQlvJU18r2H3',
#     '_score': 4.8311243,
#     '_source': {'product_id': 'B00W1L4MKU',
#      'product_category': 'Music',
#      'product_title': 'Black Is The New Black'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': '7JyyUXYBAiVFg570BXqe',
#     '_score': 4.8311243,
#     '_source': {'product_id': 'B007Q34UWS',
#      'product_category': 'Digital_Video_Download',
#      'product_title': 'Lewis Black: Black on Broadway'}},
#    {'_index': 'product',
#     '_type': 'product',
#     '_id': 'ie0fW3YBWQlvJU18LwxS',
#     '_score': 4.8311243,
#     '_source': {'product_id': 'B00GNCSHFE',
#      'product_category': 'Health_&_Personal_Care',
#      'product_title': 'Black Magic Mystical Squirmy (Black)'}}]}}

# %% [markdown]
# ### Save user_item_df and item_df for later usage

# %%
ui_df.to_pickle("user_item_df.p")
item_df.to_pickle("item_df.p")

# %%
# %store elastic_search_endpoint
# Out:
# Stored 'elastic_search_endpoint' (str)
